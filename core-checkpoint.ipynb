# %% [markdown]
# # Inferring a Conceptual Schema for a Data Lake

# %% [markdown]
# ## Create D3L Indexes.

# %% [markdown]
# The first step in the process is to create D3L indexes that store and provide access to the underlying data.  The D3L indexes are used to underpin data profiling, support schema matching, and to provide distance functions for clustering.

# %%
from d3l.input_output.dataloaders import CSVDataLoader 
from d3l.indexing.similarity_indexes import NameIndex, FormatIndex, ValueIndex, EmbeddingIndex, DistributionIndex
from d3l.indexing.similarity_indexes import NameIndex, FormatIndex, ValueIndex, EmbeddingIndex, DistributionIndex
from d3l.input_output.dataloaders import PostgresDataLoader, CSVDataLoader
from d3l.querying.query_engine import QueryEngine
from d3l.utils.functions import pickle_python_object, unpickle_python_object

# %% [markdown]
# The data lake is a folder containing csv files, reachable through data_path.

# %%
data_path='Test01/'
gt_clusters='Test01/Test01_clusters.txt' # Ground Truth Clusters

# %%
from d3l.input_output.dataloaders import CSVDataLoader 
from d3l.indexing.similarity_indexes import NameIndex, FormatIndex, ValueIndex, EmbeddingIndex, DistributionIndex
from d3l.indexing.similarity_indexes import NameIndex, FormatIndex, ValueIndex, EmbeddingIndex, DistributionIndex
from d3l.input_output.dataloaders import PostgresDataLoader, CSVDataLoader
from d3l.querying.query_engine import QueryEngine
from d3l.utils.functions import pickle_python_object, unpickle_python_object
import os
def create_or_find_indexes(data_path):
        
    #  collection of tables 
        dataloader = CSVDataLoader(
            root_path = (data_path),
            # sep=",",
            encoding='latin-1'
        )

        # NameIndex
        if os.path.isfile(os.path.join(data_path,'./name.lsh')):
            name_index = unpickle_python_object(os.path.join(data_path,'./name.lsh'))
        else:
            name_index = NameIndex(dataloader=dataloader)
            pickle_python_object(name_index,os.path.join(data_path,'./name.lsh'))
        
        # FormatIndex 
        if os.path.isfile(os.path.join(data_path,'./format.lsh')):
            format_index = unpickle_python_object(os.path.join(data_path,'./format.lsh'))
        else:
            format_index = FormatIndex(dataloader=dataloader)
            pickle_python_object(format_index,os.path.join(data_path,'./format.lsh'))     
       
        # ValueIndex 
        if os.path.isfile(os.path.join(data_path,'./value.lsh')):
            value_index = unpickle_python_object(os.path.join(data_path,'./value.lsh'))
        else:    
            value_index = ValueIndex(dataloader=dataloader)
            pickle_python_object(value_index,os.path.join(data_path, './value.lsh'))
    
        # DistributionIndex 
        if os.path.isfile(os.path.join(data_path,'./distribution.lsh')):
            distribution_index = unpickle_python_object(os.path.join(data_path,'./distribution.lsh'))
        else:
            distribution_index = DistributionIndex(dataloader=dataloader)
            pickle_python_object(distribution_index,os.path.join(data_path, './distribution.lsh'))
            
        return [name_index,format_index,value_index,distribution_index]

# %%
indexes = create_or_find_indexes(data_path)

# %% [markdown]
# # Clustering

# %% [markdown]
# The clustering process has several steps, which start with identifying how many clusters to create. The clustering algorithm used is DBSCAN, so the number of clusters created is not a parameter, but rather values need to be identified for specific configutation parameters.

# %% [markdown]
# The clustering makes use of a distance matrix, which initialised based on the neighbours from a D3L search. The distances that are not the maximum (1) are the distances to the k nearest neighbours in the D3L search based on the given indexes.

# %%
import os
def get_files(data_path):
    T = os.listdir(data_path)
    T = [t[:-4] for t in T if t.endswith('.csv')]
    T.sort()
    return(T)

# %%
import statistics
def initialise_distance_matrix(dim, L, dataloader, data_path, indexes):

    D = np.ones ((dim, dim))
    T = get_files(data_path)

    #Things are the same as themselves
    for i in range(dim):
        D[i,i] = 0

    for t in T: 
        # qe = QueryEngine(name_index, format_index, value_index, distribution_index)
        qe = QueryEngine(*indexes)

        Neighbours = qe.table_query(table=dataloader.read_table(table_name=t),
            aggregator=None, k=10)

        for n in Neighbours: #index
            (name, similarities) = n   #'car', [1.0, 0.4, 0.4, 0.0]
                
            if (name in L and t != name): 
                D[L[t], L[name]] = 1 - statistics.mean(similarities)
                D[L[name], L[t]] = 1 - statistics.mean(similarities)

    return D

# %% [markdown]
# The clustering algorithm used is DBSCAN, which has two main parameters, eps and min_samples. These parameters control the number of parameters produced.  To identify suitable values for the given application, a search is carried out over a range of different values for these parameters.  The parameter search returns values for eps and min_samples that together that gave the highest silhouette_score.

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn import metrics
from time import time

def dbscan_param_search(data_path,indexes):

    dataloader = CSVDataLoader(root_path = (data_path), encoding='latin-1')

    T = get_files(data_path)

    L ={}
    for i, t in enumerate(T): 
        L[t] = i

    # before_distance_matrix = time()     
    
    D =initialise_distance_matrix(len(T),L,dataloader,data_path,indexes)
    
    # after_distance_matrix = time()
    # print("Building distance matrix took ",{after_distance_matrix-before_distance_matrix}," sec to run.")

    Z=pd.DataFrame(D) 
    
    # Defining the list of hyperparameters to try
    eps_list=np.arange(start=0.1, stop=5, step=0.1)
    min_sample_list=np.arange(start=2, stop=25, step=1)

    # Creating empty data frame to store the silhouette scores for each trials
    silhouette_scores_data=pd.DataFrame()
    for eps_trial in eps_list:

        for min_sample_trial in min_sample_list:
            # Generating DBSCAN clusters
            db= DBSCAN(eps=eps_trial, min_samples=min_sample_trial).fit(Z)

            labels= db.labels_
            n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
            
            if n_clusters > 1:
                sil_score=metrics.silhouette_score(Z,labels)
            else:
                continue
            trial_parameters="eps:" + str(eps_trial.round(1)) +" min_sample :" + str(min_sample_trial)
            
            silhouette_scores_data=silhouette_scores_data.append(pd.DataFrame(data=[[sil_score,eps_trial.round(1),min_sample_trial]], columns=["score", "eps","min_sample"]))
        
    # Finding out the best hyperparameters with highest Score
    par=silhouette_scores_data.sort_values(by=['score'], axis=0, ascending=False).head(1)
    eps=par.iloc[0][1]
    min_sample=par.iloc[0][2]
    return eps,min_sample,Z,T

# %%
parameters = dbscan_param_search(data_path, indexes)
parameters
# Out:
# (0.9,
#  2.0,
#            0         1         2         3         4
#  0  0.000000  0.518113  0.662894  0.737599  0.750000
#  1  0.518113  0.000000  0.662894  0.689638  0.750000
#  2  0.662894  0.662894  0.000000  0.624038  0.750000
#  3  0.737599  0.689638  0.624038  0.000000  0.636694
#  4  0.750000  0.750000  0.750000  0.636694  0.000000,
#  ['film', 'movie1', 'people', 'person', 'subjects'])

# %%
def cluster_discovery(data_path,parameters):

    db = DBSCAN(eps=parameters[0],
               min_samples=parameters[1],
               n_jobs=-1)

    db.fit(parameters[2])
    labels = list(db.labels_)
    l = (parameters[3],labels)
    clust = zip(*l)
    clu = list(clust)

    return clu

# %% [markdown]
# Now we are in a position to infer the clusters for the best parameters.

# %%
clusters = cluster_discovery(data_path,parameters)

# %%
clusters
# Out:
# [('film', 0), ('movie1', 0), ('people', 1), ('person', 1), ('subjects', -1)]

# %% [markdown]
# # Cluster Quality

# %% [markdown]
# To measure the quality of the clustering relative to a ground truth clustering, the Rand Score is used.

# %%
def compute_rand_score(clusters_list,file):

    file = open(file,'r')
    content = file.read().strip()
    content_list = content.split(",")
    file.close()

    label=[]
    for member in clusters_list:
        label.append(member[1]) 

    rand_score = metrics.rand_score(content_list, label)

    return rand_score

# %%
compute_rand_score(clusters,gt_clusters)
# Out:
# 0.8

# %% [markdown]
# # Inferring Relationships Between Clusters

# %% [markdown]
# # Profiling

# %% [markdown]
# The inference of relationships depends on several types of profiling data, in particular primary keys and foreign keys.  These are inferred, again making extensive use of D3L indexes.

# %% [markdown]
# Primary key inference returns not only the attributes that are inferred to be primary keys, but also the values of these attributes.  This is because the values are required later in relationship inference.

# %%
from itertools import chain, combinations
import pandas as pd
import os
import glob


def key_options(items):
        return chain.from_iterable(combinations(items, r) for r in range(1, 2))
        # return chain.from_iterable(combinations(items, r) for r in range(1, len(items)+1))

def primary_key_discovery(data_path):
    PK=[]
    
    csv_files = glob.glob(os.path.join(data_path, "*.csv"))

    for f in csv_files:
        dataframes = pd.read_csv(f, dtype='unicode', encoding='latin-1')


        # print('Filename ',f)
        
        for candidate in key_options(list(dataframes)[0:]): #columns names
            deduped = dataframes.drop_duplicates(candidate)
            # print('    Candidate:', candidate,': len(dataframes.index) = ', len(dataframes.index), '; len(deduped.index) = ', len(deduped.index))
            if len(deduped.index) == len(dataframes.index):
                # x=[','.join(candidate)]
                x=list(candidate)
                PK_DF=dataframes[list(candidate)]
                PK.append((f,PK_DF))      
                
    return PK

# %%
primary_keys = primary_key_discovery(data_path)
primary_keys
# Out:
# [('Test01/subjects.csv',
#        Name
#   0   Steve
#   1   Abdul
#   2  Antony
#   3   Hafiz
#   4   Karen
#   5   Mario),
#  ('Test01/subjects.csv',
#     Nationality
#   0   Minecraft
#   1       Sudan
#   2          UK
#   3    Pakistan
#   4      France
#   5      Mexico),
#  ('Test01/subjects.csv',
#                        Favourite
#   0          Return of the King
#   1              The Two Towers
#   2  The Fellowship of the Ring
#   3      Raiders of the Lost Ark
#   4                        Jaws
#   5          Remains of the Day ),
#  ('Test01/people.csv',
#      person
#   0    Nour
#   1   Nohan
#   2    Muna
#   3   Seham
#   4   Bader
#   5  Othman),
#  ('Test01/people.csv',
#     income
#   0     500
#   1     680
#   2     720
#   3     845
#   4    1200
#   5    1325),
#  ('Test01/people.csv',
#      like-movie
#   0     Pyaasa
#   1     Lagaan
#   2    Nayakan
#   3    Drishyam
#   4  Jalsaghar
#   5  Charulata ),
#  ('Test01/film.csv',
#           title
#   0     Pyaasa
#   1     Lagaan
#   2    Nayakan
#   3    Drishyam
#   4  Jalsaghar
#   5  Charulata ),
#  ('Test01/film.csv',
#         income
#   0    2000000
#   1   15480000
#   2    4000000
#   3    3200000
#   4    5600000
#   5  784000000),
#  ('Test01/person.csv',
#        name
#   0    Nour
#   1   Nohan
#   2    Muna
#   3   Seham
#   4   Bader
#   5  Othman),
#  ('Test01/person.csv',
#     height
#   0     165
#   1     171
#   2     170
#   3     150
#   4     183
#   5     185),
#  ('Test01/person.csv',
#     Favourite-movie
#   0          Pyaasa
#   1          Lagaan
#   2         Nayakan
#   3        Drishyam
#   4       Jalsaghar
#   5       Charulata),
#  ('Test01/movie1.csv',
#           title
#   0     Pyaasa
#   1     Lagaan
#   2    Nayakan
#   3    Drishyam
#   4  Jalsaghar
#   5  Charulata ),
#  ('Test01/movie1.csv',
#         income
#   0    2000000
#   1   15480000
#   2    4000000
#   3    3200000
#   4    5600000
#   5  784000000)]

# %%
def foreign_key(indexes,PK,data_path):
    results=[] #value index of data sets
    threshold = 0.1
    FK=[]
    for index,tuple in enumerate(PK):
        tablename = os.path.basename(tuple[0])[:-4]


        df=tuple[1]
        column_names = list(df.columns)


        #Only consider unary keys
        if (len(column_names) == 1):
            column_name = column_names[0]
            search_result = indexes[2].query(query=df[column_name], k=10) 

            search_attribute = tablename + "." + column_name
            # print ('Search attribute: ', search_attribute)
            for (attribute,score) in search_result:
                relationship = (search_attribute,attribute)
                # print ('    Retrieves: ', attribute, '(',score,')' )
                if not(relationship in FK) and (score > threshold) and not (search_attribute == attribute):
                    FK.append(relationship)
                    
    return [list(elem) for elem in FK]

# %%
foreign_keys = foreign_key(indexes,primary_keys,data_path)
foreign_keys
# Out:
# [['people.person', 'person.name'],
#  ['people.like-movie', 'person.Favourite-movie'],
#  ['people.like-movie', 'film.title'],
#  ['people.like-movie', 'movie1.title'],
#  ['film.title', 'person.Favourite-movie'],
#  ['film.title', 'people.like-movie'],
#  ['film.title', 'movie1.title'],
#  ['person.name', 'people.person'],
#  ['person.Favourite-movie', 'people.like-movie'],
#  ['person.Favourite-movie', 'film.title'],
#  ['person.Favourite-movie', 'movie1.title'],
#  ['movie1.title', 'person.Favourite-movie'],
#  ['movie1.title', 'people.like-movie'],
#  ['movie1.title', 'film.title']]

# %% [markdown]
# # Schema Matching

# %% [markdown]
# Schema matching identifies pairwise associations between potentially similar columns.
# For now, the matching uses the D3L name index.

# %%
def match_sources(indexes,data_path):

    csv_files = glob.glob(os.path.join(data_path, "*.csv")) 
    results=[]


    for f in csv_files:
        df = pd.read_csv(f,encoding='latin-1')
        tablename = os.path.basename(f)[:-4]
        list_of_column_names = list(df.columns)

        for i in list_of_column_names:
            search_result = indexes[0].query(query=i)
            search_attribute = tablename + "." + i

            for (attribute,score) in search_result:
                match = (search_attribute,attribute,score)
                if not(match in results) and not (search_attribute == attribute):
                    match1 = (search_attribute,attribute)
                    results.append(match1)
    return [list(elem) for elem in results]

# %%
matches = match_sources(indexes,data_path)
matches
# Out:
# [['subjects.Name', 'person.name'],
#  ['subjects.Nationality', 'person.nationality'],
#  ['subjects.Favourite', 'person.Favourite-movie'],
#  ['people.person', 'person'],
#  ['people.age', 'person.age'],
#  ['people.income ', 'movie1.income'],
#  ['people.income ', 'film.income'],
#  ['film.title', 'movie1.title'],
#  ['film.income', 'movie1.income'],
#  ['film.income', 'people.income '],
#  ['person.name', 'subjects.Name'],
#  ['person.age', 'people.age'],
#  ['person.nationality', 'subjects.Nationality'],
#  ['person.Favourite-movie', 'subjects.Favourite'],
#  ['movie1.title', 'film.title'],
#  ['movie1.income', 'people.income '],
#  ['movie1.income', 'film.income']]

# %% [markdown]
# # Inferring Relationships Between Clusters

# %% [markdown]
# Relationships between clusters are postulated to exist whenever foreign keys
# exist between cluster members.  Foreign keys between cluster members are assumed
# to represent the same relationship between clusters when they involve matching attributes.

# %%
def match(type1, attribute1, type2, attribute2, matches):
    ta1 = type1 + "." + attribute1
    ta2 = type2 + "." + attribute2
    match1 = [ta1,ta2]
    match2 = [ta2,ta1]
    return ((match1 in matches) or (match2 in matches) or ((type1 == type2) and (attribute1 == attribute2)))

# %%
def remove_duplicates(Groups):
    # The groups within the relationships can contain the same item twice
    # with the foreign keys reversed.
    result = []
    for g in Groups:
        repeat = False
        for r in result:
            overlap = 0
            for gm in g:
                first = gm[0]
                second = gm[1]
                if [second,first] in r:
                    overlap = overlap + 1
            if (overlap == len(g)):
                repeat = True
                break
        if (not repeat):
            result.append(g)
    return result

# %%
import itertools
def relations_infer(clusters,matches,foreign_keys):
    clu=dict(clusters)
    Groups=[] #relationship in the ER model 
    
    list_foreign_key=[]
    for k in foreign_keys:
        li = [elem.split(".") for elem in k]
        list_foreign_key.append(list(itertools.chain.from_iterable(li)))

    for f in list_foreign_key: 
        # Only consider relationships between different clusters
        if (clu[f[0]]!=clu[f[2]]):
            # print('Foreign key: ', f, clu[f[0]], clu[f[2]])
            if len(Groups)==0:
                Groups.append([f])
            else:
                added = False
                for g in Groups: 
                    # print('Group: ', g)
                    Match_Count = 0
                    for gm in g:
                        # print('match(f[0], f[1], gm[0], gm[1], matches):', match(f[0], f[1], gm[0], gm[1], matches))
                        # print('match(f[2], f[3], gm[2], gm[3], matches):', match(f[2], f[3], gm[2], gm[3], matches))
                        # print('clu[f[0]]==clu[gm[0]]:', clu[f[0]]==clu[gm[0]])
                        # print('clu[f[2]]==clu[gm[2]:', clu[f[2]]==clu[gm[2]])
                        if(match(f[0], f[1], gm[0], gm[1], matches) and
                           match(f[2], f[3], gm[2], gm[3], matches) and
                            (clu[f[0]]==clu[gm[0]]) and
                            (clu[f[2]]==clu[gm[2]]) and
                            (clu[f[0]]!= -1) and (clu[f[2]]!= -1)):
                        
                            Match_Count= Match_Count + 1

                    if Match_Count == len(g):
                        g.append(f)
                        added = True
                        break
            
                if not added:
                    Groups.append([f])  
                
    # Return to foreign key format
    result = []
    for g in Groups:
        groupcopy = []
        for gm in g:
            first = gm[0] + '.' + gm[1]
            second = gm[2] + '.' + gm[3]
            groupcopy.append([first,second])
        result.append(groupcopy) 
    return remove_duplicates(result)

# %%
relationships = relations_infer(clusters,matches,foreign_keys)
relationships
# Out:
# [[['people.like-movie', 'film.title'], ['people.like-movie', 'movie1.title']],
#  [['film.title', 'person.Favourite-movie'],
#   ['movie1.title', 'person.Favourite-movie']]]

# %% [markdown]
# # Relationship Similarity

# %% [markdown]
# Relationship similarity is based on the rand score.  However, the rand score asusmes two partitions of the same set of elements, and here we are not guarantee to have the same elements in the ground truth and in the result of relationship inference.  Hence, we also reduce the rand score, taking into account elements that are present in the algorithm result but missing in the ground truth.  The general definition follows that from wikipedia.

# %%
# Return the set of pairs in the list
def pairs(list):
    res = res = [(a, b) for idx, a in enumerate(list) for b in list[idx + 1:]]
    return res

# %%
# a is the number of pairs of elements in the same subset in the Ground Truth that
# are in the same subset in the computed result.
def compute_a(GroundTruth, Computed):
    a = 0
    for gt_element in GroundTruth:
        for gt_pair in pairs(gt_element):
            gt_pair_set = set(gt_pair)
            for c_element in Computed:
                if gt_pair_set.issubset(set(c_element)):
                    a = a + 1
                    break
    return a

# b is the number of pairs of elements in different subsets in the Ground Truth that
# are in different subsets in the computed result.
def compute_b(GroundTruth, Computed):
    b = 0
    for gt_element1 in GroundTruth:
        for gt_element2 in GroundTruth:
            if gt_element1 != gt_element2:
                for gt_m1 in gt_element1:
                    for gt_m2 in gt_element2:
                        different = False
                        for c_element1 in Computed:
                            for c_element2 in Computed:
                                if c_element1 != c_element2 and \
                                    gt_m1 in c_element1 and gt_m2 in c_element2:
                                    # print(gt_m1,gt_m2,c_element1, c_element2)
                                    different = True
                        if different:
                            b = b + 1
    return (b // 2) # As each found twice - could iterate less!

# c is the number of pairs of elements in the same subset in the Ground Truth that
# are in different subsets in the computed result.
def compute_c(GroundTruth, Computed):
    c = 0
    for gt_element in GroundTruth:
        for (gt_m1,gt_m2) in pairs(gt_element):
            different = False
            for c_element1 in Computed:
                for c_element2 in Computed:
                    if c_element1 != c_element2 and gt_m1 in c_element1 and gt_m2 in c_element2:
                        # print(gt_element,c_element1,c_element2)
                        different = True
            if different:
                c = c + 1
    return c

# d is the number of pairs of elements in different subsets in the Ground Truth that
# are in the same subset in the computed result.
def compute_d(GroundTruth, Computed):
    d = 0
    for gt_element1 in GroundTruth:
        for gt_element2 in GroundTruth:
            if gt_element1 != gt_element2:
                for gt_m1 in gt_element1:
                    for gt_m2 in gt_element2:
                        gt_pair_set = {gt_m1, gt_m2}                
                        for c_element in Computed:
                            # print(gt_m1,gt_m2,c_element)
                            if gt_pair_set.issubset(set(c_element)):
                                # print(gt_m1,gt_m2,c_element)
                                d = d + 1
                                break
    return (d // 2) # As each found twice - could iterate less!

# e is the new error factor that is the number of elements that are in the GroundTruth
# but not computed, or the other way around
def compute_e(GroundTruth, Computed):
    flattenedGT = set(sum(GroundTruth, []))
    flattenedComputed = set(sum(Computed, []))
    diff1 = len(flattenedGT - flattenedComputed)
    diff2 = len(flattenedComputed - flattenedGT)
    return (diff1 + diff2)

# %%
GT1 = [['A','B'],['C','D']]
C1 = [['A','B'],['C'],['D']]
C2 = [['A','B','C','D']]
C3 = [['A','B'],['C'],['D'],['G']]
C4 = [['A','B'],['C']]
C5 = [['A'],['B'],['C'],['D']]
print('compute_a(GT1, GT1): ',compute_a(GT1, GT1))
print('compute_a(GT1, C1): ',compute_a(GT1, C1))
print('compute_a(GT1, C3): ',compute_a(GT1, C3))
print('compute_a(GT1, C4): ',compute_a(GT1, C4))
print('compute_b(GT1, GT1): ',compute_b(GT1, GT1))
print('compute_b(GT1, C1): ',compute_b(GT1, C1))
print('compute_b(GT1, C2): ',compute_b(GT1, C2))
print('compute_b(GT1, C3): ',compute_b(GT1, C3))
print('compute_b(GT1, C4): ',compute_b(GT1, C4))
print('compute_c(GT1, GT1): ',compute_c(GT1, GT1))
print('compute_c(GT1, C1): ',compute_c(GT1, C1))
print('compute_c(C1, GT1): ',compute_c(C1,GT1))
print('compute_c(GT1, C3): ',compute_c(GT1, C3))
print('compute_c(GT1, C4): ',compute_c(GT1, C4))
print('compute_d(GT1, GT1): ',compute_d(GT1, GT1))
print('compute_d(GT1, C1): ',compute_d(GT1, C1))
print('compute_d(GT1, C2): ',compute_d(GT1, C1))
print('compute_d(C2, GT1): ',compute_d(GT1, C1))
print('compute_d(GT1, C3): ',compute_d(GT1, C3))
print('compute_d(GT1, C4): ',compute_d(GT1, C4))
print('compute_e(GT1, GT1): ',compute_e(GT1, GT1))
print('compute_e(GT1, C1): ',compute_e(GT1, C1))
print('compute_e(GT1, C3): ',compute_e(GT1, C3))
print('compute_e(GT1, C4): ',compute_e(GT1, C4))
# Out:
# compute_a(GT1, GT1):  2
# compute_a(GT1, C1):  1
# compute_a(GT1, C3):  1
# compute_a(GT1, C4):  1
# compute_b(GT1, GT1):  4
# compute_b(GT1, C1):  4
# compute_b(GT1, C2):  0
# compute_b(GT1, C3):  4
# compute_b(GT1, C4):  2
# compute_c(GT1, GT1):  0
# compute_c(GT1, C1):  1
# compute_c(C1, GT1):  0
# compute_c(GT1, C3):  1
# compute_c(GT1, C4):  0
# compute_d(GT1, GT1):  0
# compute_d(GT1, C1):  0
# compute_d(GT1, C2):  0
# compute_d(C2, GT1):  0
# compute_d(GT1, C3):  0
# compute_d(GT1, C4):  0
# compute_e(GT1, GT1):  0
# compute_e(GT1, C1):  0
# compute_e(GT1, C3):  1
# compute_e(GT1, C4):  1

# %%
def revised_rand_score(GroundTruth, Computed):
    a = compute_a(GroundTruth, Computed)
    b = compute_b(GroundTruth, Computed)
    c = compute_c(GroundTruth, Computed)
    d = compute_d(GroundTruth, Computed)
    e = compute_e(GroundTruth, Computed)
    print('a = ', a)
    print('b = ', b)
    print('c = ', c)
    print('d = ', d)
    print('e = ', e)
    rand = (a + b) / (a + b + c + d + e)
    return rand

# %%
print('revised_rand_score(GT1, GT1): ',revised_rand_score(GT1, GT1))
print('revised_rand_score(GT1, C1): ',revised_rand_score(GT1, C1))
print('revised_rand_score(GT1, C2): ',revised_rand_score(GT1, C2))
print('revised_rand_score(GT1, C3): ',revised_rand_score(GT1, C3))
print('revised_rand_score(GT1, C4): ',revised_rand_score(GT1, C4))
print('revised_rand_score(GT1, C5): ',revised_rand_score(GT1, C5))
# Out:
# a =  2
# b =  4
# c =  0
# d =  0
# e =  0
# revised_rand_score(GT1, GT1):  1.0
# a =  1
# b =  4
# c =  1
# d =  0
# e =  0
# revised_rand_score(GT1, C1):  0.8333333333333334
# a =  2
# b =  0
# c =  0
# d =  4
# e =  0
# revised_rand_score(GT1, C2):  0.3333333333333333
# a =  1
# b =  4
# c =  1
# d =  0
# e =  1
# revised_rand_score(GT1, C3):  0.7142857142857143
# a =  1
# b =  2
# c =  0
# d =  0
# e =  1
# revised_rand_score(GT1, C4):  0.75
# a =  0
# b =  4
# c =  2
# d =  0
# e =  0
# revised_rand_score(GT1, C5):  0.6666666666666666

# %% [markdown]
# The ground truth is stored in a file of the form: m1, m2, m3; m4, m5; m6.  Semicolons separate relationships between clusters, and each mi is a foreign key.

# %%
# For the rand score, we need each foreign key to have a name as a string.
def canonical_fk(foreign_key):
    s = foreign_key[0]
    e = foreign_key[1]
    
    if s < e:
        result = "(" + s + "+" + e + ")"
    else:
        result = "(" + e + "+" + s + ")"
    
    return result

# %%
def compute_rand_score_relationships(relationships,file):

    file = open(file,'r')
    content = file.read().replace("\n", "")
    content = content.replace(" ", "")
    file.close()
    
    # Convert foreign keys in the relationships into canonical strings 
    canonical_relationships = []
    for group in relationships:
        rel_member = []
        for member in group:
            rel_member.append(canonical_fk(member))
        canonical_relationships.append(rel_member)

    # Convert foreign keys in the input file into canonical strings
    GT=[]
    group_list = content.split(";")
    for group in group_list:
        member_list = group.split(",")
        
        GT_member = []
        for member in member_list:
            foreign_key = member.split("+")                
            GT_member.append(canonical_fk(foreign_key))
            
        GT.append(GT_member)
        
    score = revised_rand_score(GT, canonical_relationships)

    return score

# %%
compute_rand_score_relationships(relationships, 'Test01/Test01_relationships.txt')
# Out:
# a =  2
# b =  4
# c =  0
# d =  0
# e =  2
# 0.75

# %% [markdown]
# # Run an Expertiment

# %% [markdown]
# The following script will run a complete experiment, including computing the cluster and relationship rand scores for a data set.

# %%
from time import time
def run_experiment(data_path, gt_clusters, gt_relationships):

    # Identify the types through clustering

    start = time()
    indexes = create_or_find_indexes(data_path)
    after_indexes = time()     
    print("Building indexes took ",{after_indexes-start}," sec to run.")
    parameters = dbscan_param_search(data_path, indexes)
    after_parameters = time()
    print("Parameter Search took ",{after_parameters-after_indexes}," sec to run.")
    clusters = cluster_discovery(data_path,parameters)
    after_clustering = time()
    print("Clustering took       ",{after_clustering-after_parameters}," sec to run.")
    clusters_rand_score = compute_rand_score(clusters,gt_clusters)

    # Infer the relationships
    before_profiling = time()
    primary_keys = primary_key_discovery(data_path)
    foreign_keys = foreign_key(indexes,primary_keys,data_path)
    before_matching = time()
    print("Profiling took        ",{before_matching-before_profiling}," sec to run.")
    matches = match_sources(indexes,data_path)
    before_relationships = time()
    print("Matching took         ",{before_relationships-before_matching}," sec to run.")
    relationships = relations_infer(clusters,matches,foreign_keys)
    after_relationships = time()
    print("Relationships took    ",{after_relationships-before_relationships}," sec to run.")
    relationships_rand_score = compute_rand_score_relationships(relationships, gt_relationships)

    print('Cluster Rand Score       = ',clusters_rand_score)
    print('Relationships Rand Score = ',relationships_rand_score)
    
    return [clusters,relationships,foreign_keys]

# %%
# The test case
data_path='Test01/'
gt_clusters='Test01/Test01_clusters.txt'
gt_relationships='Test01/Test01_relationships.txt' # Ground Truth Relationships
result = run_experiment(data_path, gt_clusters, gt_relationships)
result
# Out:
# Building indexes took  {0.005330801010131836}  sec to run.
# Parameter Search took  {1.324878215789795}  sec to run.
# Clustering took        {0.005598783493041992}  sec to run.
# Profiling took         {0.06081986427307129}  sec to run.
# Matching took          {0.0231020450592041}  sec to run.
# Relationships took     {0.0002269744873046875}  sec to run.
# a =  2
# b =  4
# c =  0
# d =  0
# e =  2
# Cluster Rand Score       =  0.8
# Relationships Rand Score =  0.75
# [[('film', 0), ('movie1', 0), ('people', 1), ('person', 1), ('subjects', -1)],
#  [[['people.like-movie', 'film.title'], ['people.like-movie', 'movie1.title']],
#   [['film.title', 'person.Favourite-movie'],
#    ['movie1.title', 'person.Favourite-movie']]],
#  [['people.person', 'person.name'],
#   ['people.like-movie', 'person.Favourite-movie'],
#   ['people.like-movie', 'film.title'],
#   ['people.like-movie', 'movie1.title'],
#   ['film.title', 'person.Favourite-movie'],
#   ['film.title', 'people.like-movie'],
#   ['film.title', 'movie1.title'],
#   ['person.name', 'people.person'],
#   ['person.Favourite-movie', 'people.like-movie'],
#   ['person.Favourite-movie', 'film.title'],
#   ['person.Favourite-movie', 'movie1.title'],
#   ['movie1.title', 'person.Favourite-movie'],
#   ['movie1.title', 'people.like-movie'],
#   ['movie1.title', 'film.title']]]

# %%
# Cities from T2D
data_path='T2DGroundTruth/city_things' # Folder containing the csv files of the data
gt_clusters='T2DGroundTruth/city_things/cluster_gt.txt' # Ground Truth Clusters
gt_relationships='Test01/Test01_relationships.txt' # Ground Truth Relationships
result = run_experiment(data_path, gt_clusters, gt_relationships)
result
# Out:
# Building indexes took  {0.0756220817565918}  sec to run.
# /Users/normanpaton/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/histograms.py:906: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# Parameter Search took  {10.526529788970947}  sec to run.
# Clustering took        {0.005774021148681641}  sec to run.
# Profiling took         {0.6445529460906982}  sec to run.
# Matching took          {1.1247119903564453}  sec to run.
# Relationships took     {0.0005459785461425781}  sec to run.
# a =  0
# b =  0
# c =  0
# d =  0
# e =  7
# Cluster Rand Score       =  0.7404081632653061
# Relationships Rand Score =  0.0
# [[('Airport0', -1),
#   ('Airport13', 0),
#   ('Airport14', -1),
#   ('Airport15', 0),
#   ('Airport2', 1),
#   ('Airport20', 2),
#   ('Airport3', 0),
#   ('Airport30', -1),
#   ('Airport34', -1),
#   ('Airport38', 0),
#   ('Airport4', 1),
#   ('Airport40', 1),
#   ('Airport42', 3),
#   ('Airport48', 1),
#   ('Airport7', 1),
#   ('City1', 2),
#   ('City11', 2),
#   ('City12', 2),
#   ('City16', 2),
#   ('City21', -1),
#   ('City25', 2),
#   ('City27', 4),
#   ('City37', 2),
#   ('City44', 2),
#   ('City45', -1),
#   ('City46', 2),
#   ('City47', 5),
#   ('City6', -1),
#   ('Museum10', 6),
#   ('Museum17', -1),
#   ('Museum22', 6),
#   ('Museum26', 6),
#   ('Museum28', 2),
#   ('Museum29', 2),
#   ('Museum41', -1),
#   ('Museum43', 6),
#   ('Museum8', 3),
#   ('University18', 7),
#   ('University19', 5),
#   ('University23', 5),
#   ('University24', 5),
#   ('University31', 5),
#   ('University32', 7),
#   ('University33', 4),
#   ('University35', 0),
#   ('University36', 2),
#   ('University39', -1),
#   ('University49', 5),
#   ('University5', -1),
#   ('University9', 3)],
#  [[['City47.Date', 'Airport13.%change']]],
#  [['Airport15.code', 'Airport38.code'],
#   ['University19.University', 'University31.University'],
#   ['University19.University', 'University49.University'],
#   ['University31.University', 'University49.University'],
#   ['University31.University', 'University19.University'],
#   ['Museum43.museum', 'Museum22.museum'],
#   ['Museum43.museum', 'Museum10.museum'],
#   ['Museum43.museum', 'Museum26.museum'],
#   ['Airport38.code', 'Airport15.code'],
#   ['Museum22.museum', 'Museum10.museum'],
#   ['Museum22.museum', 'Museum43.museum'],
#   ['Museum22.museum', 'Museum26.museum'],
#   ['Airport48.code', 'Airport40.code'],
#   ['Airport48.code', 'Airport2.code'],
#   ['Airport48.code', 'Airport4.code'],
#   ['Airport48.code', 'Airport7.code'],
#   ['Airport48.airport name', 'Airport40.airport name'],
#   ['Airport48.airport name', 'Airport2.airport name'],
#   ['Airport48.airport name', 'Airport4.airport name'],
#   ['Airport48.airport name', 'Airport7.airport name'],
#   ['Airport48.airport name', 'Airport4.city'],
#   ['Airport48.airport name', 'Airport7.city'],
#   ['Airport48.airport name', 'Airport40.city'],
#   ['Airport48.airport name', 'Airport2.city'],
#   ['Airport48.airport name', 'Airport48.city'],
#   ['Museum26.museum', 'Museum22.museum'],
#   ['Museum26.museum', 'Museum10.museum'],
#   ['Museum26.museum', 'Museum43.museum'],
#   ['City47.Date', 'Airport13.%change'],
#   ['Airport40.code', 'Airport48.code'],
#   ['Airport40.code', 'Airport2.code'],
#   ['Airport40.code', 'Airport4.code'],
#   ['Airport40.code', 'Airport7.code'],
#   ['Airport40.airport name', 'Airport48.airport name'],
#   ['Airport40.airport name', 'Airport2.airport name'],
#   ['Airport40.airport name', 'Airport4.airport name'],
#   ['Airport40.airport name', 'Airport7.airport name'],
#   ['Airport40.airport name', 'Airport4.city'],
#   ['Airport40.airport name', 'Airport7.city'],
#   ['Airport40.airport name', 'Airport40.city'],
#   ['Airport40.airport name', 'Airport2.city'],
#   ['Airport40.airport name', 'Airport48.city'],
#   ['Museum10.museum', 'Museum22.museum'],
#   ['Museum10.museum', 'Museum43.museum'],
#   ['Museum10.museum', 'Museum26.museum'],
#   ['University49.University', 'University31.University'],
#   ['University49.University', 'University19.University'],
#   ['Airport2.code', 'Airport40.code'],
#   ['Airport2.code', 'Airport48.code'],
#   ['Airport2.code', 'Airport4.code'],
#   ['Airport2.code', 'Airport7.code'],
#   ['Airport2.airport name', 'Airport40.airport name'],
#   ['Airport2.airport name', 'Airport48.airport name'],
#   ['Airport2.airport name', 'Airport4.airport name'],
#   ['Airport2.airport name', 'Airport7.airport name'],
#   ['Airport2.airport name', 'Airport4.city'],
#   ['Airport2.airport name', 'Airport7.city'],
#   ['Airport2.airport name', 'Airport40.city'],
#   ['Airport2.airport name', 'Airport2.city'],
#   ['Airport2.airport name', 'Airport48.city'],
#   ['Airport4.code', 'Airport40.code'],
#   ['Airport4.code', 'Airport48.code'],
#   ['Airport4.code', 'Airport2.code'],
#   ['Airport4.code', 'Airport7.code'],
#   ['Airport4.airport name', 'Airport40.airport name'],
#   ['Airport4.airport name', 'Airport48.airport name'],
#   ['Airport4.airport name', 'Airport2.airport name'],
#   ['Airport4.airport name', 'Airport7.airport name'],
#   ['Airport4.airport name', 'Airport4.city'],
#   ['Airport4.airport name', 'Airport7.city'],
#   ['Airport4.airport name', 'Airport40.city'],
#   ['Airport4.airport name', 'Airport2.city'],
#   ['Airport4.airport name', 'Airport48.city'],
#   ['Airport7.code', 'Airport40.code'],
#   ['Airport7.code', 'Airport48.code'],
#   ['Airport7.code', 'Airport2.code'],
#   ['Airport7.code', 'Airport4.code'],
#   ['Airport7.airport name', 'Airport40.airport name'],
#   ['Airport7.airport name', 'Airport48.airport name'],
#   ['Airport7.airport name', 'Airport2.airport name'],
#   ['Airport7.airport name', 'Airport4.airport name'],
#   ['Airport7.airport name', 'Airport4.city'],
#   ['Airport7.airport name', 'Airport7.city'],
#   ['Airport7.airport name', 'Airport40.city'],
#   ['Airport7.airport name', 'Airport2.city'],
#   ['Airport7.airport name', 'Airport48.city']]]

# %%
# Cities from T2D: Name index Only
data_path='T2DGroundTruth/city_things' # Folder containing the csv files of the data
gt_clusters='T2DGroundTruth/city_things/cluster_gt.txt' # Ground Truth Clusters
gt_relationships='Test01/Test01_relationships.txt' # Ground Truth Relationships

start = time()
indexes = create_or_find_indexes(data_path)
after_indexes = time()     
print("Building indexes took ",{after_indexes-start}," sec to run.")
parameters = dbscan_param_search(data_path, [indexes[0]]) # Here is the name index only change
after_parameters = time()
print("Parameter Search took ",{after_parameters-after_indexes}," sec to run.")
clusters = cluster_discovery(data_path,parameters)
after_clustering = time()
print("Clustering took       ",{after_clustering-after_parameters}," sec to run.")
clusters_rand_score = compute_rand_score(clusters,gt_clusters)

# Infer the relationships
before_profiling = time()
primary_keys = primary_key_discovery(data_path)
foreign_keys = foreign_key(indexes,primary_keys,data_path)
before_matching = time()
print("Profiling took        ",{before_matching-before_profiling}," sec to run.")
matches = match_sources(indexes,data_path)
before_relationships = time()
print("Matching took         ",{before_relationships-before_matching}," sec to run.")
relationships = relations_infer(clusters,matches,foreign_keys)
after_relationships = time()
print("Relationships took    ",{after_relationships-before_relationships}," sec to run.")
relationships_rand_score = compute_rand_score_relationships(relationships, gt_relationships)

print('Cluster Rand Score       = ',clusters_rand_score)
print('Relationships Rand Score = ',relationships_rand_score)
    
[clusters,relationships,foreign_keys]
# Out:
# Building indexes took  {0.017621994018554688}  sec to run.
# Parameter Search took  {3.277867078781128}  sec to run.
# Clustering took        {0.006243705749511719}  sec to run.
# Profiling took         {0.6386520862579346}  sec to run.
# Matching took          {1.2118661403656006}  sec to run.
# Relationships took     {0.00037598609924316406}  sec to run.
# a =  0
# b =  0
# c =  0
# d =  0
# e =  7
# Cluster Rand Score       =  0.7616326530612245
# Relationships Rand Score =  0.0
# [[('Airport0', 0),
#   ('Airport13', 1),
#   ('Airport14', -1),
#   ('Airport15', 1),
#   ('Airport2', 2),
#   ('Airport20', -1),
#   ('Airport3', 1),
#   ('Airport30', -1),
#   ('Airport34', -1),
#   ('Airport38', 1),
#   ('Airport4', 2),
#   ('Airport40', 2),
#   ('Airport42', 0),
#   ('Airport48', 2),
#   ('Airport7', 2),
#   ('City1', 3),
#   ('City11', 4),
#   ('City12', 5),
#   ('City16', 4),
#   ('City21', 5),
#   ('City25', -1),
#   ('City27', 6),
#   ('City37', 3),
#   ('City44', 5),
#   ('City45', 0),
#   ('City46', 4),
#   ('City47', 7),
#   ('City6', 0),
#   ('Museum10', 8),
#   ('Museum17', -1),
#   ('Museum22', 8),
#   ('Museum26', 8),
#   ('Museum28', 7),
#   ('Museum29', -1),
#   ('Museum41', 0),
#   ('Museum43', 8),
#   ('Museum8', 0),
#   ('University18', 9),
#   ('University19', 7),
#   ('University23', 7),
#   ('University24', 7),
#   ('University31', 7),
#   ('University32', 9),
#   ('University33', 6),
#   ('University35', 0),
#   ('University36', 7),
#   ('University39', 6),
#   ('University49', 7),
#   ('University5', 6),
#   ('University9', 0)],
#  [[['City47.Date', 'Airport13.%change']]],
#  [['Airport15.code', 'Airport38.code'],
#   ['University19.University', 'University31.University'],
#   ['University19.University', 'University49.University'],
#   ['University31.University', 'University49.University'],
#   ['University31.University', 'University19.University'],
#   ['Museum43.museum', 'Museum22.museum'],
#   ['Museum43.museum', 'Museum10.museum'],
#   ['Museum43.museum', 'Museum26.museum'],
#   ['Airport38.code', 'Airport15.code'],
#   ['Museum22.museum', 'Museum10.museum'],
#   ['Museum22.museum', 'Museum43.museum'],
#   ['Museum22.museum', 'Museum26.museum'],
#   ['Airport48.code', 'Airport40.code'],
#   ['Airport48.code', 'Airport2.code'],
#   ['Airport48.code', 'Airport4.code'],
#   ['Airport48.code', 'Airport7.code'],
#   ['Airport48.airport name', 'Airport40.airport name'],
#   ['Airport48.airport name', 'Airport2.airport name'],
#   ['Airport48.airport name', 'Airport4.airport name'],
#   ['Airport48.airport name', 'Airport7.airport name'],
#   ['Airport48.airport name', 'Airport4.city'],
#   ['Airport48.airport name', 'Airport7.city'],
#   ['Airport48.airport name', 'Airport40.city'],
#   ['Airport48.airport name', 'Airport2.city'],
#   ['Airport48.airport name', 'Airport48.city'],
#   ['Museum26.museum', 'Museum22.museum'],
#   ['Museum26.museum', 'Museum10.museum'],
#   ['Museum26.museum', 'Museum43.museum'],
#   ['City47.Date', 'Airport13.%change'],
#   ['Airport40.code', 'Airport48.code'],
#   ['Airport40.code', 'Airport2.code'],
#   ['Airport40.code', 'Airport4.code'],
#   ['Airport40.code', 'Airport7.code'],
#   ['Airport40.airport name', 'Airport48.airport name'],
#   ['Airport40.airport name', 'Airport2.airport name'],
#   ['Airport40.airport name', 'Airport4.airport name'],
#   ['Airport40.airport name', 'Airport7.airport name'],
#   ['Airport40.airport name', 'Airport4.city'],
#   ['Airport40.airport name', 'Airport7.city'],
#   ['Airport40.airport name', 'Airport40.city'],
#   ['Airport40.airport name', 'Airport2.city'],
#   ['Airport40.airport name', 'Airport48.city'],
#   ['Museum10.museum', 'Museum22.museum'],
#   ['Museum10.museum', 'Museum43.museum'],
#   ['Museum10.museum', 'Museum26.museum'],
#   ['University49.University', 'University31.University'],
#   ['University49.University', 'University19.University'],
#   ['Airport2.code', 'Airport40.code'],
#   ['Airport2.code', 'Airport48.code'],
#   ['Airport2.code', 'Airport4.code'],
#   ['Airport2.code', 'Airport7.code'],
#   ['Airport2.airport name', 'Airport40.airport name'],
#   ['Airport2.airport name', 'Airport48.airport name'],
#   ['Airport2.airport name', 'Airport4.airport name'],
#   ['Airport2.airport name', 'Airport7.airport name'],
#   ['Airport2.airport name', 'Airport4.city'],
#   ['Airport2.airport name', 'Airport7.city'],
#   ['Airport2.airport name', 'Airport40.city'],
#   ['Airport2.airport name', 'Airport2.city'],
#   ['Airport2.airport name', 'Airport48.city'],
#   ['Airport4.code', 'Airport40.code'],
#   ['Airport4.code', 'Airport48.code'],
#   ['Airport4.code', 'Airport2.code'],
#   ['Airport4.code', 'Airport7.code'],
#   ['Airport4.airport name', 'Airport40.airport name'],
#   ['Airport4.airport name', 'Airport48.airport name'],
#   ['Airport4.airport name', 'Airport2.airport name'],
#   ['Airport4.airport name', 'Airport7.airport name'],
#   ['Airport4.airport name', 'Airport4.city'],
#   ['Airport4.airport name', 'Airport7.city'],
#   ['Airport4.airport name', 'Airport40.city'],
#   ['Airport4.airport name', 'Airport2.city'],
#   ['Airport4.airport name', 'Airport48.city'],
#   ['Airport7.code', 'Airport40.code'],
#   ['Airport7.code', 'Airport48.code'],
#   ['Airport7.code', 'Airport2.code'],
#   ['Airport7.code', 'Airport4.code'],
#   ['Airport7.airport name', 'Airport40.airport name'],
#   ['Airport7.airport name', 'Airport48.airport name'],
#   ['Airport7.airport name', 'Airport2.airport name'],
#   ['Airport7.airport name', 'Airport4.airport name'],
#   ['Airport7.airport name', 'Airport4.city'],
#   ['Airport7.airport name', 'Airport7.city'],
#   ['Airport7.airport name', 'Airport40.city'],
#   ['Airport7.airport name', 'Airport2.city'],
#   ['Airport7.airport name', 'Airport48.city']]]

# %%
# Films, artists, etc, from T2D
data_path='T2DGroundTruth/culture_things' # Folder containing the csv files of the data
gt_clusters='T2DGroundTruth/culture_things/cluster_gt.txt' # Ground Truth Clusters
gt_relationships='Test01/Test01_relationships.txt' # Ground Truth Relationships

start = time()
indexes = create_or_find_indexes(data_path)
after_indexes = time()     
print("Building indexes took ",{after_indexes-start}," sec to run.")
parameters = dbscan_param_search(data_path, indexes)
after_parameters = time()
print("Parameter Search took ",{after_parameters-after_indexes}," sec to run.")
clusters = cluster_discovery(data_path,parameters)
after_clustering = time()
print("Clustering took       ",{after_clustering-after_parameters}," sec to run.")
clusters_rand_score = compute_rand_score(clusters,gt_clusters)

# Infer the relationships
before_profiling = time()
primary_keys = primary_key_discovery(data_path)
foreign_keys = foreign_key(indexes,primary_keys,data_path)
before_matching = time()
print("Profiling took        ",{before_matching-before_profiling}," sec to run.")
matches = match_sources(indexes,data_path)
before_relationships = time()
print("Matching took         ",{before_relationships-before_matching}," sec to run.")
relationships = relations_infer(clusters,matches,foreign_keys)
after_relationships = time()
print("Relationships took    ",{after_relationships-before_relationships}," sec to run.")
relationships_rand_score = compute_rand_score_relationships(relationships, gt_relationships)

print('Cluster Rand Score       = ',clusters_rand_score)
print('Relationships Rand Score = ',relationships_rand_score)
    
[clusters,relationships,foreign_keys]
# Out:
# Building indexes took  {0.08339405059814453}  sec to run.
# /Users/normanpaton/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/histograms.py:906: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# Parameter Search took  {9.704152822494507}  sec to run.
# Clustering took        {0.005705833435058594}  sec to run.
# Profiling took         {0.6986198425292969}  sec to run.
# Matching took          {1.1324989795684814}  sec to run.
# Relationships took     {0.002100229263305664}  sec to run.
# a =  0
# b =  0
# c =  0
# d =  0
# e =  11
# Cluster Rand Score       =  0.6247379454926625
# Relationships Rand Score =  0.0
# [[('Album31', -1),
#   ('EurovisionSongContestEntry28', 0),
#   ('EurovisionSongContestEntry35', 0),
#   ('EurovisionSongContestEntry9', 0),
#   ('Film11', -1),
#   ('Film12', -1),
#   ('Film13', 1),
#   ('Film14', -1),
#   ('Film15', -1),
#   ('Film16', -1),
#   ('Film18', -1),
#   ('Film19', 1),
#   ('Film20', -1),
#   ('Film21', 1),
#   ('Film22', -1),
#   ('Film25', 1),
#   ('Film29', -1),
#   ('Film32', -1),
#   ('Film36', -1),
#   ('Film38', 1),
#   ('Film39', -1),
#   ('Film4', 1),
#   ('Film43', -1),
#   ('Film44', 1),
#   ('Film45', -1),
#   ('Film47', -1),
#   ('Film48', -1),
#   ('Film5', 2),
#   ('Film50', -1),
#   ('Film51', -1),
#   ('Film6', 1),
#   ('Film7', -1),
#   ('MusicalWork0', 2),
#   ('MusicalWork10', 2),
#   ('MusicalWork17', -1),
#   ('MusicalWork2', -1),
#   ('MusicalWork26', 2),
#   ('MusicalWork27', -1),
#   ('MusicalWork3', -1),
#   ('MusicalWork33', 2),
#   ('MusicalWork34', -1),
#   ('MusicalWork37', 2),
#   ('MusicalWork40', -1),
#   ('MusicalWork42', 2),
#   ('MusicalWork46', 2),
#   ('MusicalWork52', -1),
#   ('MusicalWork53', -1),
#   ('Song1', -1),
#   ('Song23', -1),
#   ('Song24', 2),
#   ('Song30', -1),
#   ('Song41', 0),
#   ('Song49', 0),
#   ('Song8', 0)],
#  [[['EurovisionSongContestEntry28.Draw', 'Film7.view date']],
#   [['EurovisionSongContestEntry9.Draw', 'Film7.view date']],
#   [['EurovisionSongContestEntry9.Draw', 'Film29.unit price']],
#   [['EurovisionSongContestEntry9.Place', 'Film29.unit price']],
#   [['EurovisionSongContestEntry35.Draw', 'Film7.view date']]],
#  [['Film50.Id', 'Film39.FilmId'],
#   ['EurovisionSongContestEntry28.Draw', 'Film7.view date'],
#   ['MusicalWork2.#', 'MusicalWork17.#'],
#   ['Song41.Singer(s)', 'Song49.Singer(s)'],
#   ['Song41.Country', 'Song49.Country'],
#   ['Film39.FilmId', 'Film50.Id'],
#   ['MusicalWork17.#', 'MusicalWork2.#'],
#   ['Song49.Singer(s)', 'Song41.Singer(s)'],
#   ['Song49.Country', 'Song41.Country'],
#   ['EurovisionSongContestEntry9.Draw', 'Film7.view date'],
#   ['EurovisionSongContestEntry9.Draw', 'Film29.unit price'],
#   ['EurovisionSongContestEntry9.Country',
#    'EurovisionSongContestEntry35.Country'],
#   ['EurovisionSongContestEntry9.Place', 'Film29.unit price'],
#   ['EurovisionSongContestEntry35.Draw', 'Film7.view date'],
#   ['EurovisionSongContestEntry35.Country',
#    'EurovisionSongContestEntry9.Country']]]

# %%
# Films, artists, etc, from T2D: Name Index Only
data_path='T2DGroundTruth/culture_things' # Folder containing the csv files of the data
gt_clusters='T2DGroundTruth/culture_things/cluster_gt.txt' # Ground Truth Clusters
gt_relationships='Test01/Test01_relationships.txt' # Ground Truth Relationships

start = time()
indexes = create_or_find_indexes(data_path)
after_indexes = time()     
print("Building indexes took ",{after_indexes-start}," sec to run.")
parameters = dbscan_param_search(data_path, [indexes[0]]) # Here is the name index only change
after_parameters = time()
print("Parameter Search took ",{after_parameters-after_indexes}," sec to run.")
clusters = cluster_discovery(data_path,parameters)
after_clustering = time()
print("Clustering took       ",{after_clustering-after_parameters}," sec to run.")
clusters_rand_score = compute_rand_score(clusters,gt_clusters)

# Infer the relationships
before_profiling = time()
primary_keys = primary_key_discovery(data_path)
foreign_keys = foreign_key(indexes,primary_keys,data_path)
before_matching = time()
print("Profiling took        ",{before_matching-before_profiling}," sec to run.")
matches = match_sources(indexes,data_path)
before_relationships = time()
print("Matching took         ",{before_relationships-before_matching}," sec to run.")
relationships = relations_infer(clusters,matches,foreign_keys)
after_relationships = time()
print("Relationships took    ",{after_relationships-before_relationships}," sec to run.")
relationships_rand_score = compute_rand_score_relationships(relationships, gt_relationships)

print('Cluster Rand Score       = ',clusters_rand_score)
print('Relationships Rand Score = ',relationships_rand_score)
    
[clusters,relationships,foreign_keys]
# Out:
# Building indexes took  {0.02438974380493164}  sec to run.
# Parameter Search took  {3.1192100048065186}  sec to run.
# Clustering took        {0.006070137023925781}  sec to run.
# Profiling took         {0.6988098621368408}  sec to run.
# Matching took          {1.1416051387786865}  sec to run.
# Relationships took     {0.0019960403442382812}  sec to run.
# a =  0
# b =  0
# c =  0
# d =  0
# e =  11
# Cluster Rand Score       =  0.6778476589797344
# Relationships Rand Score =  0.0
# [[('Album31', -1),
#   ('EurovisionSongContestEntry28', 0),
#   ('EurovisionSongContestEntry35', 0),
#   ('EurovisionSongContestEntry9', 0),
#   ('Film11', 1),
#   ('Film12', 2),
#   ('Film13', 3),
#   ('Film14', 4),
#   ('Film15', -1),
#   ('Film16', 1),
#   ('Film18', 2),
#   ('Film19', 3),
#   ('Film20', 1),
#   ('Film21', 3),
#   ('Film22', -1),
#   ('Film25', 3),
#   ('Film29', -1),
#   ('Film32', 2),
#   ('Film36', 4),
#   ('Film38', 3),
#   ('Film39', 5),
#   ('Film4', 3),
#   ('Film43', 2),
#   ('Film44', 3),
#   ('Film45', -1),
#   ('Film47', -1),
#   ('Film48', 4),
#   ('Film5', -1),
#   ('Film50', 5),
#   ('Film51', 1),
#   ('Film6', 3),
#   ('Film7', -1),
#   ('MusicalWork0', 6),
#   ('MusicalWork10', 6),
#   ('MusicalWork17', 7),
#   ('MusicalWork2', 7),
#   ('MusicalWork26', 8),
#   ('MusicalWork27', 2),
#   ('MusicalWork3', 2),
#   ('MusicalWork33', 8),
#   ('MusicalWork34', 2),
#   ('MusicalWork37', 6),
#   ('MusicalWork40', -1),
#   ('MusicalWork42', 6),
#   ('MusicalWork46', 8),
#   ('MusicalWork52', 2),
#   ('MusicalWork53', 2),
#   ('Song1', -1),
#   ('Song23', 9),
#   ('Song24', 7),
#   ('Song30', 9),
#   ('Song41', 10),
#   ('Song49', 10),
#   ('Song8', 10)],
#  [[['EurovisionSongContestEntry28.Draw', 'Film7.view date']],
#   [['EurovisionSongContestEntry9.Draw', 'Film7.view date']],
#   [['EurovisionSongContestEntry9.Draw', 'Film29.unit price']],
#   [['EurovisionSongContestEntry9.Place', 'Film29.unit price']],
#   [['EurovisionSongContestEntry35.Draw', 'Film7.view date']]],
#  [['Film50.Id', 'Film39.FilmId'],
#   ['EurovisionSongContestEntry28.Draw', 'Film7.view date'],
#   ['MusicalWork2.#', 'MusicalWork17.#'],
#   ['Song41.Singer(s)', 'Song49.Singer(s)'],
#   ['Song41.Country', 'Song49.Country'],
#   ['Film39.FilmId', 'Film50.Id'],
#   ['MusicalWork17.#', 'MusicalWork2.#'],
#   ['Song49.Singer(s)', 'Song41.Singer(s)'],
#   ['Song49.Country', 'Song41.Country'],
#   ['EurovisionSongContestEntry9.Draw', 'Film7.view date'],
#   ['EurovisionSongContestEntry9.Draw', 'Film29.unit price'],
#   ['EurovisionSongContestEntry9.Country',
#    'EurovisionSongContestEntry35.Country'],
#   ['EurovisionSongContestEntry9.Place', 'Film29.unit price'],
#   ['EurovisionSongContestEntry35.Draw', 'Film7.view date'],
#   ['EurovisionSongContestEntry35.Country',
#    'EurovisionSongContestEntry9.Country']]]

# %%
# NHS Organisation Data
data_path='NHS' # Folder containing the csv files of the data
gt_clusters='NHS/nhs_gt.txt' # Ground Truth Clusters
gt_relationships='NHS/nhs_rels_gt.txt' # Ground Truth Relationships

start = time()
indexes = create_or_find_indexes(data_path)
after_indexes = time()     
print("Building indexes took ",{after_indexes-start}," sec to run.")
parameters = dbscan_param_search(data_path, indexes)
after_parameters = time()
print("Parameter Search took ",{after_parameters-after_indexes}," sec to run.")
clusters = cluster_discovery(data_path,parameters)
after_clustering = time()
print("Clustering took       ",{after_clustering-after_parameters}," sec to run.")
clusters_rand_score = compute_rand_score(clusters,gt_clusters)

before_profiling = time()
primary_keys = primary_key_discovery(data_path)
foreign_keys = foreign_key(indexes,primary_keys,data_path)
before_matching = time()
print("Profiling took        ",{before_matching-before_profiling}," sec to run.")
matches = match_sources(indexes,data_path)
before_relationships = time()
print("Matching took         ",{before_relationships-before_matching}," sec to run.")
relationships = relations_infer(clusters,matches,foreign_keys)
after_relationships = time()
print("Relationships took    ",{after_relationships-before_relationships}," sec to run.")
relationships_rand_score = compute_rand_score_relationships(relationships, gt_relationships)


print('Cluster Rand Score       = ',clusters_rand_score)
print('Relationships Rand Score = ',relationships_rand_score)
    
[clusters,relationships,foreign_keys]
# Out:
# Building indexes took  {0.016201019287109375}  sec to run.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# /Users/normanpaton/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/histograms.py:906: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# Parameter Search took  {93.47871279716492}  sec to run.
# Clustering took        {0.005606174468994141}  sec to run.
# Profiling took         {4.967548847198486}  sec to run.
# <ipython-input-110-e985584d97d4>:23: DtypeWarning: Columns (11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   matches = match_sources(indexes,data_path)
# Matching took          {3.6103100776672363}  sec to run.
# Relationships took     {0.002137899398803711}  sec to run.
# a =  3
# b =  9
# c =  3
# d =  0
# e =  0
# Cluster Rand Score       =  0.7017543859649122
# Relationships Rand Score =  0.8
# [[('CCG-2', 0),
#   ('Clinics-2', 0),
#   ('DentistOpeningTimes-2', 1),
#   ('Dentists-2', 0),
#   ('GPOpeningTimes-2', 1),
#   ('GPPractices-2', 0),
#   ('GPServices-2', -1),
#   ('GP_2', 0),
#   ('GSD', 0),
#   ('Hospital-2', 0),
#   ('LAT-2', 0),
#   ('OpticianOpeningTimes-2', 1),
#   ('Pharmacy-2', 0),
#   ('PharmacyOpeningTimes-2', 1),
#   ('PharmacyServices-2', -1),
#   ('SCL-2', 0),
#   ('SCLServices-2', -1),
#   ('SCP-2', 0),
#   ('TransparencyIndicatorsDentistsPerformance-2', -1)],
#  [[['Dentists-2.OrganisationID', 'DentistOpeningTimes-2.OrganisationId'],
#    ['Pharmacy-2.OrganisationID', 'PharmacyOpeningTimes-2.OrganisationId'],
#    ['GP_2.OrganisationID', 'GPOpeningTimes-2.OrganisationId']],
#   [['SCL-2.OrganisationID', 'SCLServices-2.OrganisationID']],
#   [['Pharmacy-2.OrganisationID', 'PharmacyServices-2.OrganisationID']],
#   [['GP_2.OrganisationID', 'GPServices-2.OrganisationID']]],
#  [['Dentists-2.OrganisationID', 'DentistOpeningTimes-2.OrganisationId'],
#   ['SCL-2.OrganisationID', 'SCLServices-2.OrganisationID'],
#   ['Pharmacy-2.OrganisationID', 'PharmacyOpeningTimes-2.OrganisationId'],
#   ['Pharmacy-2.OrganisationID', 'PharmacyServices-2.OrganisationID'],
#   ['GP_2.OrganisationID', 'GPOpeningTimes-2.OrganisationId'],
#   ['GP_2.OrganisationID', 'GPServices-2.OrganisationID'],
#   ['GP_2.OrganisationCode', 'GPPractices-2.OrganisationCode'],
#   ['CCG-2.OrganisationCode', 'GP_2.ParentODSCode'],
#   ['CCG-2.OrganisationName', 'GP_2.ParentName']]]

# %%
# NHS Organisation Data: Name index Only
data_path='NHS' # Folder containing the csv files of the data
gt_clusters='NHS/nhs_gt.txt' # Ground Truth Clusters
gt_relationships='NHS/nhs_rels_gt.txt' # Ground Truth Relationships

start = time()
indexes = create_or_find_indexes(data_path)
after_indexes = time()     
print("Building indexes took ",{after_indexes-start}," sec to run.")
parameters = dbscan_param_search(data_path, [indexes[0]]) # Here is the name index only change
after_parameters = time()
print("Parameter Search took ",{after_parameters-after_indexes}," sec to run.")
clusters = cluster_discovery(data_path,parameters)
after_clustering = time()
print("Clustering took       ",{after_clustering-after_parameters}," sec to run.")
clusters_rand_score = compute_rand_score(clusters,gt_clusters)

before_profiling = time()
primary_keys = primary_key_discovery(data_path)
foreign_keys = foreign_key(indexes,primary_keys,data_path)
before_matching = time()
print("Profiling took        ",{before_matching-before_profiling}," sec to run.")
matches = match_sources(indexes,data_path)
before_relationships = time()
print("Matching took         ",{before_relationships-before_matching}," sec to run.")
relationships = relations_infer(clusters,matches,foreign_keys)
after_relationships = time()
print("Relationships took    ",{after_relationships-before_relationships}," sec to run.")
relationships_rand_score = compute_rand_score_relationships(relationships, gt_relationships)


print('Cluster Rand Score       = ',clusters_rand_score)
print('Relationships Rand Score = ',relationships_rand_score)
    
[clusters,relationships,foreign_keys]
# Out:
# Building indexes took  {0.01576399803161621}  sec to run.
# Parameter Search took  {4.972355127334595}  sec to run.
# Clustering took        {0.005866050720214844}  sec to run.
# Profiling took         {5.234174966812134}  sec to run.
# <ipython-input-111-cc035f12c200>:23: DtypeWarning: Columns (11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   matches = match_sources(indexes,data_path)
# Matching took          {3.4856932163238525}  sec to run.
# Relationships took     {0.002218961715698242}  sec to run.
# a =  0
# b =  8
# c =  6
# d =  1
# e =  0
# Cluster Rand Score       =  0.5497076023391813
# Relationships Rand Score =  0.5333333333333333
# [[('CCG-2', 0),
#   ('Clinics-2', -1),
#   ('DentistOpeningTimes-2', -1),
#   ('Dentists-2', 0),
#   ('GPOpeningTimes-2', 1),
#   ('GPPractices-2', 0),
#   ('GPServices-2', 1),
#   ('GP_2', 0),
#   ('GSD', 0),
#   ('Hospital-2', -1),
#   ('LAT-2', -1),
#   ('OpticianOpeningTimes-2', 1),
#   ('Pharmacy-2', -1),
#   ('PharmacyOpeningTimes-2', 1),
#   ('PharmacyServices-2', 1),
#   ('SCL-2', -1),
#   ('SCLServices-2', 1),
#   ('SCP-2', 0),
#   ('TransparencyIndicatorsDentistsPerformance-2', -1)],
#  [[['Dentists-2.OrganisationID', 'DentistOpeningTimes-2.OrganisationId']],
#   [['SCL-2.OrganisationID', 'SCLServices-2.OrganisationID']],
#   [['Pharmacy-2.OrganisationID', 'PharmacyOpeningTimes-2.OrganisationId']],
#   [['Pharmacy-2.OrganisationID', 'PharmacyServices-2.OrganisationID']],
#   [['GP_2.OrganisationID', 'GPOpeningTimes-2.OrganisationId'],
#    ['GP_2.OrganisationID', 'GPServices-2.OrganisationID']]],
#  [['Dentists-2.OrganisationID', 'DentistOpeningTimes-2.OrganisationId'],
#   ['SCL-2.OrganisationID', 'SCLServices-2.OrganisationID'],
#   ['Pharmacy-2.OrganisationID', 'PharmacyOpeningTimes-2.OrganisationId'],
#   ['Pharmacy-2.OrganisationID', 'PharmacyServices-2.OrganisationID'],
#   ['GP_2.OrganisationID', 'GPOpeningTimes-2.OrganisationId'],
#   ['GP_2.OrganisationID', 'GPServices-2.OrganisationID'],
#   ['GP_2.OrganisationCode', 'GPPractices-2.OrganisationCode'],
#   ['CCG-2.OrganisationCode', 'GP_2.ParentODSCode'],
#   ['CCG-2.OrganisationName', 'GP_2.ParentName']]]

# %%
primary_keys = primary_key_discovery(data_path)
foreign_keys = foreign_key(indexes,primary_keys,data_path)

# %%
primary_keys
# Out:
# [('NHS/Dentists-2.csv',
#        OrganisationID
#   0               K26
#   1               K27
#   2               K28
#   3               K60
#   4               K61
#   ...             ...
#   7370      K10954962
#   7371      K10954963
#   7372      K10954964
#   7373      K10954965
#   7374      K10954966
#
#   [7375 rows x 1 columns]),
#  ('NHS/Dentists-2.csv',
#        OrganisationCode
#   0             V000203
#   1             V004490
#   2             V008165
#   3             V006985
#   4             V006940
#   ...               ...
#   7370          V203705
#   7371          V203859
#   7372          V204369
#   7373          V032182
#   7374          V032195
#
#   [7375 rows x 1 columns]),
#  ('NHS/Hospital-2.csv',
#        OrganisationID
#   0            K17970
#   1            K17981
#   2            K18102
#   3            K18138
#   4            K18142
#   ...             ...
#   1194      K10943515
#   1195      K10943516
#   1196      K10953840
#   1197      K10953844
#   1198      K10953845
#
#   [1199 rows x 1 columns]),
#  ('NHS/Hospital-2.csv',
#        OrganisationCode
#   0               NDA07
#   1               NDA18
#   2               NLT02
#   3               NMP01
#   4               NMV01
#   ...               ...
#   1194            RH5T8
#   1195            RH5T9
#   1196            NEF42
#   1197            GFM01
#   1198            GFM02
#
#   [1199 rows x 1 columns]),
#  ('NHS/SCL-2.csv',
#         OrganisationID
#   0            K220157
#   1            K220158
#   2            K220161
#   3            K220162
#   4            K220163
#   ...              ...
#   25702      K10955403
#   25703      K10955404
#   25704      K10955405
#   25705      K10955406
#   25706      K10955407
#
#   [25707 rows x 1 columns]),
#  ('NHS/Pharmacy-2.csv',
#         OrganisationID
#   0             K13043
#   1             K13046
#   2             K13049
#   3             K13054
#   4             K13062
#   ...              ...
#   11056      K10954771
#   11057      K10954772
#   11058      K10955048
#   11059      K10955049
#   11060      K10955121
#
#   [11061 rows x 1 columns]),
#  ('NHS/Pharmacy-2.csv',
#         OrganisationCode
#   0                FA512
#   1                FAP38
#   2                FC826
#   3                FD294
#   4                FJF07
#   ...                ...
#   11056            FFP58
#   11057            FT335
#   11058            FCK62
#   11059            FKK74
#   11060            FH464
#
#   [11061 rows x 1 columns]),
#  ('NHS/GP_2.csv',
#        OrganisationID
#   0             K2915
#   1             K3028
#   2             K3029
#   3             K3031
#   4             K3033
#   ...             ...
#   9070      K10955078
#   9071      K10955079
#   9072      K10955080
#   9073      K10955123
#   9074      K10955124
#
#   [9075 rows x 1 columns]),
#  ('NHS/GP_2.csv',
#        OrganisationCode
#   0              Y02622
#   1              A81001
#   2              A81002
#   3              A81004
#   4              A81005
#   ...               ...
#   9070        B84016001
#   9071        B84012003
#   9072        B84012002
#   9073           Y06810
#   9074        H81119002
#
#   [9075 rows x 1 columns]),
#  ('NHS/LAT-2.csv',
#      OrganisationID
#   0         K463098
#   1         K463099
#   2         K463100
#   3         K463101
#   4         K463102
#   5         K463103
#   6         K463104
#   7         K463105
#   8         K463120
#   9         K463121
#   10        K463122
#   11        K463123
#   12        K463124
#   13        K463125
#   14        K463126
#   15        K463127
#   16        K463128
#   17        K463129
#   18        K463130
#   19        K463131
#   20        K463132
#   21        K463133
#   22        K463134
#   23        K463135
#   24        K463136
#   25       K3884932
#   26       K3884933
#   27       K3884934
#   28       K3884939
#   29       K3884940
#   30       K3884944),
#  ('NHS/LAT-2.csv',
#      OrganisationCode
#   0               Q64
#   1               Q65
#   2               Q66
#   3               Q67
#   4               Q68
#   5               Q69
#   6               Q70
#   7               Q71
#   8               Q44
#   9               Q45
#   10              Q46
#   11              Q47
#   12              Q48
#   13              Q49
#   14              Q50
#   15              Q51
#   16              Q52
#   17              Q53
#   18              Q54
#   19              Q55
#   20              Q56
#   21              Q57
#   22              Q58
#   23              Q59
#   24              Q60
#   25            T1470
#   26            T1150
#   27            T1310
#   28            T1450
#   29            T1490
#   30            T1480),
#  ('NHS/LAT-2.csv',
#                                        OrganisationName
#   0   Bath, Gloucestershire, Swindon And Wiltshire A...
#   1                  NHS England ï¿½ South (South West)
#   2       Devon, Cornwall And Isles Of Scilly Area Team
#   3                           NHS England ï¿½South East
#   4                    NHS England - South (South East)
#   5                             Thames Valley Area Team
#   6                                    Wessex Area Team
#   7                                    London Area Team
#   8           Cheshire, Warrington And Wirral Area Team
#   9               Durham, Darlington And Tees Area Team
#   10                       Greater Manchester Area Team
#   11                               Lancashire Area Team
#   12                               Merseyside Area Team
#   13   Cumbria, Northumberland, Tyne And Wear Area Team
#   14               North Yorkshire And Humber Area Team
#   15            South Yorkshire And Bassetlaw Area Team
#   16                           West Yorkshire Area Team
#   17  Arden, Herefordshire And Worcestershire Area Team
#   18         Birmingham And The Black Country Area Team
#   19           Derbyshire And Nottinghamshire Area Team
#   20                              East Anglia Area Team
#   21                                    Essex Area Team
#   22     Hertfordshire And The South Midlands Area Team
#   23          Leicestershire And Lincolnshire Area Team
#   24             Shropshire And Staffordshire Area Team
#   25                  Nhs Commissioning Board Authority
#   26                                     NHS Resolution
#   27                           Health Protection Agency
#   28                    Nhs Business Services Authority
#   29                    NHS Trust Development Authority
#   30                          Health Research Authority),
#  ('NHS/Clinics-2.csv',
#         OrganisationID
#   0             K12366
#   1             K12450
#   2             K12461
#   3             K17937
#   4             K17938
#   ...              ...
#   18920      K10955102
#   18921      K10955103
#   18922      K10955105
#   18923      K10955107
#   18924      K10955108
#
#   [18925 rows x 1 columns]),
#  ('NHS/GPPractices-2.csv',
#        OrganisationID
#   0            K46946
#   1            K46947
#   2            K46948
#   3            K46949
#   4            K46950
#   ...             ...
#   6927      K10802863
#   6928      K10921142
#   6929      K10921201
#   6930      K10942814
#   6931      K10955122
#
#   [6932 rows x 1 columns]),
#  ('NHS/SCP-2.csv',
#         OrganisationID
#   0            K207506
#   1            K207507
#   2            K207509
#   3            K207510
#   4            K207511
#   ...              ...
#   14575      K10955179
#   14576      K10955380
#   14577      K10955381
#   14578      K10955382
#   14579      K10955383
#
#   [14580 rows x 1 columns]),
#  ('NHS/CCG-2.csv',
#       OrganisationID
#   0          K462869
#   1          K462870
#   2          K462875
#   3          K462878
#   4          K462879
#   ..             ...
#   143      K10880436
#   144      K10880437
#   145      K10880438
#   146      K10880439
#   147      K10880440
#
#   [148 rows x 1 columns]),
#  ('NHS/CCG-2.csv',
#       OrganisationCode
#   0                00G
#   1                00H
#   2                00L
#   3                00X
#   4                01F
#   ..               ...
#   143              91Q
#   144              92A
#   145              92G
#   146              93C
#   147              97R
#
#   [148 rows x 1 columns]),
#  ('NHS/CCG-2.csv',
#                                         OrganisationName
#   0                     NHS Newcastle North And East CCG
#   1                               NHS Newcastle West CCG
#   2                               NHS Northumberland CCG
#   3                     NHS Chorley And South Ribble CCG
#   4                                       NHS Halton CCG
#   ..                                                 ...
#   143                            NHS Kent And Medway CCG
#   144                          NHS Surrey Heartlands CCG
#   145  NHS Bath And North East Somerset, Swindon And ...
#   146                       NHS North Central London CCG
#   147                                NHS East Sussex CCG
#
#   [148 rows x 1 columns])]

# %%
foreign_keys
# Out:
# [['Dentists-2.OrganisationID', 'DentistOpeningTimes-2.OrganisationId'],
#  ['SCL-2.OrganisationID', 'SCLServices-2.OrganisationID'],
#  ['Pharmacy-2.OrganisationID', 'PharmacyOpeningTimes-2.OrganisationId'],
#  ['Pharmacy-2.OrganisationID', 'PharmacyServices-2.OrganisationID'],
#  ['GP_2.OrganisationID', 'GPOpeningTimes-2.OrganisationId'],
#  ['GP_2.OrganisationID', 'GPServices-2.OrganisationID'],
#  ['GP_2.OrganisationCode', 'GPPractices-2.OrganisationCode'],
#  ['CCG-2.OrganisationCode', 'GP_2.ParentODSCode'],
#  ['CCG-2.OrganisationName', 'GP_2.ParentName']]

# %%
clusters
# Out:
# [('CCG-2', 0),
#  ('Clinics-2', -1),
#  ('DentistOpeningTimes-2', -1),
#  ('Dentists-2', 0),
#  ('GPOpeningTimes-2', 1),
#  ('GPPractices-2', 0),
#  ('GPServices-2', 1),
#  ('GP_2', 0),
#  ('GSD', 0),
#  ('Hospital-2', -1),
#  ('LAT-2', -1),
#  ('OpticianOpeningTimes-2', 1),
#  ('Pharmacy-2', -1),
#  ('PharmacyOpeningTimes-2', 1),
#  ('PharmacyServices-2', 1),
#  ('SCL-2', -1),
#  ('SCLServices-2', 1),
#  ('SCP-2', 0),
#  ('TransparencyIndicatorsDentistsPerformance-2', -1)]

# %%
matches
# Out:
# [['Dentists-2.OrganisationID', 'GPPractices-2.OrganisationID'],
#  ['Dentists-2.OrganisationID', 'GP_2.OrganisationID'],
#  ['Dentists-2.OrganisationID', 'SCP-2.OrganisationID'],
#  ['Dentists-2.OrganisationID', 'OpticianOpeningTimes-2.OrganisationId'],
#  ['Dentists-2.OrganisationID', 'GSD.OrganisationID'],
#  ['Dentists-2.OrganisationID', 'PharmacyOpeningTimes-2.OrganisationId'],
#  ['Dentists-2.OrganisationID', 'GPOpeningTimes-2.OrganisationId'],
#  ['Dentists-2.OrganisationID', 'CCG-2.OrganisationID'],
#  ['Dentists-2.OrganisationID', 'SCLServices-2.OrganisationID'],
#  ['Dentists-2.OrganisationID', 'Pharmacy-2.OrganisationID'],
#  ['Dentists-2.OrganisationID',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationID'],
#  ['Dentists-2.OrganisationID', 'Clinics-2.OrganisationID'],
#  ['Dentists-2.OrganisationID', 'DentistOpeningTimes-2.OrganisationId'],
#  ['Dentists-2.OrganisationID', 'SCL-2.OrganisationID'],
#  ['Dentists-2.OrganisationID', 'PharmacyServices-2.OrganisationID'],
#  ['Dentists-2.OrganisationID', 'GPServices-2.OrganisationID'],
#  ['Dentists-2.OrganisationID', 'LAT-2.OrganisationID'],
#  ['Dentists-2.OrganisationID', 'Hospital-2.OrganisationID'],
#  ['Dentists-2.OrganisationID', 'GP_2.OrganisationCode'],
#  ['Dentists-2.OrganisationID', 'SCL-2.OrganisationCode'],
#  ['Dentists-2.OrganisationID', 'GPPractices-2.OrganisationCode'],
#  ['Dentists-2.OrganisationID', 'LAT-2.OrganisationCode'],
#  ['Dentists-2.OrganisationID',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationCode'],
#  ['Dentists-2.OrganisationID', 'CCG-2.OrganisationCode'],
#  ['Dentists-2.OrganisationID', 'Clinics-2.OrganisationCode'],
#  ['Dentists-2.OrganisationID', 'Hospital-2.OrganisationCode'],
#  ['Dentists-2.OrganisationID', 'Dentists-2.OrganisationCode'],
#  ['Dentists-2.OrganisationID', 'SCP-2.OrganisationCode'],
#  ['Dentists-2.OrganisationID', 'Pharmacy-2.OrganisationCode'],
#  ['Dentists-2.OrganisationID',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationName'],
#  ['Dentists-2.OrganisationID', 'SCP-2.OrganisationName'],
#  ['Dentists-2.OrganisationID', 'Clinics-2.OrganisationName'],
#  ['Dentists-2.OrganisationID', 'LAT-2.OrganisationName'],
#  ['Dentists-2.OrganisationID', 'SCL-2.OrganisationName'],
#  ['Dentists-2.OrganisationID', 'GSD.OrganisationName'],
#  ['Dentists-2.OrganisationID', 'Pharmacy-2.OrganisationName'],
#  ['Dentists-2.OrganisationID', 'Dentists-2.OrganisationName'],
#  ['Dentists-2.OrganisationID', 'GPPractices-2.OrganisationName'],
#  ['Dentists-2.OrganisationID', 'GP_2.OrganisationName'],
#  ['Dentists-2.OrganisationID', 'Hospital-2.OrganisationName'],
#  ['Dentists-2.OrganisationID', 'CCG-2.OrganisationName'],
#  ['Dentists-2.OrganisationID', 'GP_2.OrganisationType'],
#  ['Dentists-2.OrganisationID', 'LAT-2.OrganisationType'],
#  ['Dentists-2.OrganisationID', 'GSD.OrganisationType'],
#  ['Dentists-2.OrganisationID', 'CCG-2.OrganisationType'],
#  ['Dentists-2.OrganisationID', 'SCP-2.OrganisationType'],
#  ['Dentists-2.OrganisationID', 'GPPractices-2.OrganisationType'],
#  ['Dentists-2.OrganisationID', 'Dentists-2.OrganisationType'],
#  ['Dentists-2.OrganisationID', 'SCL-2.OrganisationType'],
#  ['Dentists-2.OrganisationID', 'Hospital-2.OrganisationType'],
#  ['Dentists-2.OrganisationID', 'Clinics-2.OrganisationType'],
#  ['Dentists-2.OrganisationID', 'Pharmacy-2.OrganisationType'],
#  ['Dentists-2.OrganisationCode', 'GP_2.OrganisationCode'],
#  ['Dentists-2.OrganisationCode', 'SCL-2.OrganisationCode'],
#  ['Dentists-2.OrganisationCode', 'SCP-2.OrganisationCode'],
#  ['Dentists-2.OrganisationCode', 'GPPractices-2.OrganisationCode'],
#  ['Dentists-2.OrganisationCode', 'Clinics-2.OrganisationCode'],
#  ['Dentists-2.OrganisationCode', 'Hospital-2.OrganisationCode'],
#  ['Dentists-2.OrganisationCode', 'CCG-2.OrganisationCode'],
#  ['Dentists-2.OrganisationCode', 'LAT-2.OrganisationCode'],
#  ['Dentists-2.OrganisationCode', 'Pharmacy-2.OrganisationCode'],
#  ['Dentists-2.OrganisationCode',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationCode'],
#  ['Dentists-2.OrganisationCode', 'GPPractices-2.OrganisationID'],
#  ['Dentists-2.OrganisationCode', 'GP_2.OrganisationID'],
#  ['Dentists-2.OrganisationCode', 'SCP-2.OrganisationID'],
#  ['Dentists-2.OrganisationCode', 'OpticianOpeningTimes-2.OrganisationId'],
#  ['Dentists-2.OrganisationCode', 'Hospital-2.OrganisationID'],
#  ['Dentists-2.OrganisationCode', 'PharmacyOpeningTimes-2.OrganisationId'],
#  ['Dentists-2.OrganisationCode', 'GPOpeningTimes-2.OrganisationId'],
#  ['Dentists-2.OrganisationCode', 'CCG-2.OrganisationID'],
#  ['Dentists-2.OrganisationCode', 'Dentists-2.OrganisationID'],
#  ['Dentists-2.OrganisationCode', 'SCLServices-2.OrganisationID'],
#  ['Dentists-2.OrganisationCode', 'Pharmacy-2.OrganisationID'],
#  ['Dentists-2.OrganisationCode',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationID'],
#  ['Dentists-2.OrganisationCode', 'Clinics-2.OrganisationID'],
#  ['Dentists-2.OrganisationCode', 'DentistOpeningTimes-2.OrganisationId'],
#  ['Dentists-2.OrganisationCode', 'PharmacyServices-2.OrganisationID'],
#  ['Dentists-2.OrganisationCode', 'SCL-2.OrganisationID'],
#  ['Dentists-2.OrganisationCode', 'GPServices-2.OrganisationID'],
#  ['Dentists-2.OrganisationCode', 'LAT-2.OrganisationID'],
#  ['Dentists-2.OrganisationCode', 'GSD.OrganisationID'],
#  ['Dentists-2.OrganisationCode', 'SCP-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationCode', 'Dentists-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationCode', 'Clinics-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationCode', 'LAT-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationCode', 'GSD.OrganisationStatus'],
#  ['Dentists-2.OrganisationCode', 'Hospital-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationCode', 'SCL-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationCode', 'GP_2.OrganisationStatus'],
#  ['Dentists-2.OrganisationCode', 'GPPractices-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationCode', 'CCG-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationCode', 'Pharmacy-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationType', 'SCL-2.OrganisationType'],
#  ['Dentists-2.OrganisationType', 'SCP-2.OrganisationType'],
#  ['Dentists-2.OrganisationType', 'LAT-2.OrganisationType'],
#  ['Dentists-2.OrganisationType', 'GSD.OrganisationType'],
#  ['Dentists-2.OrganisationType', 'GP_2.OrganisationType'],
#  ['Dentists-2.OrganisationType', 'GPPractices-2.OrganisationType'],
#  ['Dentists-2.OrganisationType', 'Hospital-2.OrganisationType'],
#  ['Dentists-2.OrganisationType', 'CCG-2.OrganisationType'],
#  ['Dentists-2.OrganisationType', 'Clinics-2.OrganisationType'],
#  ['Dentists-2.OrganisationType', 'Pharmacy-2.OrganisationType'],
#  ['Dentists-2.OrganisationType', 'SCP-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationType',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationName'],
#  ['Dentists-2.OrganisationType', 'SCP-2.OrganisationName'],
#  ['Dentists-2.OrganisationType', 'Clinics-2.OrganisationName'],
#  ['Dentists-2.OrganisationType', 'Dentists-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationType', 'LAT-2.OrganisationName'],
#  ['Dentists-2.OrganisationType', 'Clinics-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationType', 'SCL-2.OrganisationName'],
#  ['Dentists-2.OrganisationType', 'GSD.OrganisationName'],
#  ['Dentists-2.OrganisationType', 'LAT-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationType', 'GSD.OrganisationStatus'],
#  ['Dentists-2.OrganisationType', 'Pharmacy-2.OrganisationName'],
#  ['Dentists-2.OrganisationType', 'Dentists-2.OrganisationName'],
#  ['Dentists-2.OrganisationType', 'GPPractices-2.OrganisationName'],
#  ['Dentists-2.OrganisationType', 'Hospital-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationType', 'GP_2.OrganisationName'],
#  ['Dentists-2.OrganisationType', 'Hospital-2.OrganisationName'],
#  ['Dentists-2.OrganisationType', 'SCL-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationType', 'GP_2.OrganisationStatus'],
#  ['Dentists-2.OrganisationType', 'GPPractices-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationType', 'CCG-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationType', 'CCG-2.OrganisationName'],
#  ['Dentists-2.OrganisationType', 'Pharmacy-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationType', 'GPPractices-2.OrganisationID'],
#  ['Dentists-2.OrganisationType', 'GP_2.OrganisationID'],
#  ['Dentists-2.OrganisationType', 'SCP-2.OrganisationID'],
#  ['Dentists-2.OrganisationType', 'OpticianOpeningTimes-2.OrganisationId'],
#  ['Dentists-2.OrganisationType', 'Hospital-2.OrganisationID'],
#  ['Dentists-2.OrganisationType', 'PharmacyOpeningTimes-2.OrganisationId'],
#  ['Dentists-2.OrganisationType', 'GPOpeningTimes-2.OrganisationId'],
#  ['Dentists-2.OrganisationType', 'CCG-2.OrganisationID'],
#  ['Dentists-2.OrganisationType', 'Dentists-2.OrganisationID'],
#  ['Dentists-2.OrganisationType', 'SCLServices-2.OrganisationID'],
#  ['Dentists-2.OrganisationType', 'Pharmacy-2.OrganisationID'],
#  ['Dentists-2.OrganisationType',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationID'],
#  ['Dentists-2.OrganisationType', 'Clinics-2.OrganisationID'],
#  ['Dentists-2.OrganisationType', 'DentistOpeningTimes-2.OrganisationId'],
#  ['Dentists-2.OrganisationType', 'SCL-2.OrganisationID'],
#  ['Dentists-2.OrganisationType', 'PharmacyServices-2.OrganisationID'],
#  ['Dentists-2.OrganisationType', 'GPServices-2.OrganisationID'],
#  ['Dentists-2.OrganisationType', 'LAT-2.OrganisationID'],
#  ['Dentists-2.OrganisationType', 'GSD.OrganisationID'],
#  ['Dentists-2.SubType', 'GP_2.SubType'],
#  ['Dentists-2.SubType', 'SCL-2.SubType'],
#  ['Dentists-2.SubType', 'Clinics-2.SubType'],
#  ['Dentists-2.SubType', 'GSD.SubType'],
#  ['Dentists-2.SubType', 'GPPractices-2.SubType'],
#  ['Dentists-2.SubType', 'CCG-2.SubType'],
#  ['Dentists-2.SubType', 'Hospital-2.SubType'],
#  ['Dentists-2.SubType', 'LAT-2.SubType'],
#  ['Dentists-2.SubType', 'SCP-2.SubType'],
#  ['Dentists-2.SubType', 'Pharmacy-2.SubType'],
#  ['Dentists-2.OrganisationStatus', 'SCP-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationStatus', 'LAT-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationStatus', 'GSD.OrganisationStatus'],
#  ['Dentists-2.OrganisationStatus', 'GPPractices-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationStatus', 'GP_2.OrganisationStatus'],
#  ['Dentists-2.OrganisationStatus', 'CCG-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationStatus', 'Hospital-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationStatus', 'Clinics-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationStatus', 'SCL-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationStatus', 'Pharmacy-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationStatus',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationName'],
#  ['Dentists-2.OrganisationStatus', 'SCP-2.OrganisationName'],
#  ['Dentists-2.OrganisationStatus', 'Clinics-2.OrganisationName'],
#  ['Dentists-2.OrganisationStatus', 'LAT-2.OrganisationName'],
#  ['Dentists-2.OrganisationStatus', 'SCL-2.OrganisationName'],
#  ['Dentists-2.OrganisationStatus', 'GSD.OrganisationName'],
#  ['Dentists-2.OrganisationStatus', 'Pharmacy-2.OrganisationName'],
#  ['Dentists-2.OrganisationStatus', 'Dentists-2.OrganisationName'],
#  ['Dentists-2.OrganisationStatus', 'GPPractices-2.OrganisationName'],
#  ['Dentists-2.OrganisationStatus', 'GP_2.OrganisationName'],
#  ['Dentists-2.OrganisationStatus', 'Hospital-2.OrganisationName'],
#  ['Dentists-2.OrganisationStatus', 'CCG-2.OrganisationName'],
#  ['Dentists-2.OrganisationStatus', 'GP_2.OrganisationType'],
#  ['Dentists-2.OrganisationStatus', 'LAT-2.OrganisationType'],
#  ['Dentists-2.OrganisationStatus', 'GSD.OrganisationType'],
#  ['Dentists-2.OrganisationStatus', 'CCG-2.OrganisationType'],
#  ['Dentists-2.OrganisationStatus', 'SCP-2.OrganisationType'],
#  ['Dentists-2.OrganisationStatus', 'GPPractices-2.OrganisationType'],
#  ['Dentists-2.OrganisationStatus', 'Dentists-2.OrganisationType'],
#  ['Dentists-2.OrganisationStatus', 'SCL-2.OrganisationType'],
#  ['Dentists-2.OrganisationStatus', 'Hospital-2.OrganisationType'],
#  ['Dentists-2.OrganisationStatus', 'Clinics-2.OrganisationType'],
#  ['Dentists-2.OrganisationStatus', 'Pharmacy-2.OrganisationType'],
#  ['Dentists-2.OrganisationStatus', 'GP_2.OrganisationCode'],
#  ['Dentists-2.OrganisationStatus', 'SCL-2.OrganisationCode'],
#  ['Dentists-2.OrganisationStatus', 'GPPractices-2.OrganisationCode'],
#  ['Dentists-2.OrganisationStatus',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationCode'],
#  ['Dentists-2.OrganisationStatus', 'LAT-2.OrganisationCode'],
#  ['Dentists-2.OrganisationStatus', 'CCG-2.OrganisationCode'],
#  ['Dentists-2.OrganisationStatus', 'Clinics-2.OrganisationCode'],
#  ['Dentists-2.OrganisationStatus', 'Hospital-2.OrganisationCode'],
#  ['Dentists-2.OrganisationStatus', 'Dentists-2.OrganisationCode'],
#  ['Dentists-2.OrganisationStatus', 'SCP-2.OrganisationCode'],
#  ['Dentists-2.OrganisationStatus', 'Pharmacy-2.OrganisationCode'],
#  ['Dentists-2.IsPimsManaged', 'GP_2.IsPimsManaged'],
#  ['Dentists-2.IsPimsManaged', 'LAT-2.IsPimsManaged'],
#  ['Dentists-2.IsPimsManaged', 'Hospital-2.IsPimsManaged'],
#  ['Dentists-2.IsPimsManaged', 'SCP-2.IsPimsManaged'],
#  ['Dentists-2.IsPimsManaged', 'Pharmacy-2.IsPimsManaged'],
#  ['Dentists-2.IsPimsManaged', 'SCL-2.IsPimsManaged'],
#  ['Dentists-2.IsPimsManaged', 'GPPractices-2.IsPimsManaged'],
#  ['Dentists-2.IsPimsManaged', 'Clinics-2.IsPimsManaged'],
#  ['Dentists-2.IsPimsManaged', 'CCG-2.IsPimsManaged'],
#  ['Dentists-2.OrganisationName', 'GP_2.OrganisationName'],
#  ['Dentists-2.OrganisationName',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationName'],
#  ['Dentists-2.OrganisationName', 'GSD.OrganisationName'],
#  ['Dentists-2.OrganisationName', 'SCP-2.OrganisationName'],
#  ['Dentists-2.OrganisationName', 'Pharmacy-2.OrganisationName'],
#  ['Dentists-2.OrganisationName', 'Clinics-2.OrganisationName'],
#  ['Dentists-2.OrganisationName', 'Hospital-2.OrganisationName'],
#  ['Dentists-2.OrganisationName', 'GPPractices-2.OrganisationName'],
#  ['Dentists-2.OrganisationName', 'CCG-2.OrganisationName'],
#  ['Dentists-2.OrganisationName', 'LAT-2.OrganisationName'],
#  ['Dentists-2.OrganisationName', 'SCL-2.OrganisationName'],
#  ['Dentists-2.OrganisationName', 'SCP-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationName', 'Dentists-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationName', 'Clinics-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationName', 'LAT-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationName', 'GSD.OrganisationStatus'],
#  ['Dentists-2.OrganisationName', 'Hospital-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationName', 'SCL-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationName', 'GP_2.OrganisationStatus'],
#  ['Dentists-2.OrganisationName', 'GPPractices-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationName', 'CCG-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationName', 'Pharmacy-2.OrganisationStatus'],
#  ['Dentists-2.OrganisationName', 'GPPractices-2.OrganisationID'],
#  ['Dentists-2.OrganisationName', 'GP_2.OrganisationID'],
#  ['Dentists-2.OrganisationName', 'SCP-2.OrganisationID'],
#  ['Dentists-2.OrganisationName', 'OpticianOpeningTimes-2.OrganisationId'],
#  ['Dentists-2.OrganisationName', 'Hospital-2.OrganisationID'],
#  ['Dentists-2.OrganisationName', 'PharmacyOpeningTimes-2.OrganisationId'],
#  ['Dentists-2.OrganisationName', 'GPOpeningTimes-2.OrganisationId'],
#  ['Dentists-2.OrganisationName', 'CCG-2.OrganisationID'],
#  ['Dentists-2.OrganisationName', 'Dentists-2.OrganisationID'],
#  ['Dentists-2.OrganisationName', 'SCLServices-2.OrganisationID'],
#  ['Dentists-2.OrganisationName', 'Pharmacy-2.OrganisationID'],
#  ['Dentists-2.OrganisationName',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationID'],
#  ['Dentists-2.OrganisationName', 'Clinics-2.OrganisationID'],
#  ['Dentists-2.OrganisationName', 'DentistOpeningTimes-2.OrganisationId'],
#  ['Dentists-2.OrganisationName', 'SCL-2.OrganisationID'],
#  ['Dentists-2.OrganisationName', 'PharmacyServices-2.OrganisationID'],
#  ['Dentists-2.OrganisationName', 'GPServices-2.OrganisationID'],
#  ['Dentists-2.OrganisationName', 'LAT-2.OrganisationID'],
#  ['Dentists-2.OrganisationName', 'GSD.OrganisationID'],
#  ['Dentists-2.OrganisationName', 'GP_2.OrganisationType'],
#  ['Dentists-2.OrganisationName', 'LAT-2.OrganisationType'],
#  ['Dentists-2.OrganisationName', 'GSD.OrganisationType'],
#  ['Dentists-2.OrganisationName', 'CCG-2.OrganisationType'],
#  ['Dentists-2.OrganisationName', 'SCP-2.OrganisationType'],
#  ['Dentists-2.OrganisationName', 'GPPractices-2.OrganisationType'],
#  ['Dentists-2.OrganisationName', 'Dentists-2.OrganisationType'],
#  ['Dentists-2.OrganisationName', 'SCL-2.OrganisationType'],
#  ['Dentists-2.OrganisationName', 'Hospital-2.OrganisationType'],
#  ['Dentists-2.OrganisationName', 'Clinics-2.OrganisationType'],
#  ['Dentists-2.OrganisationName', 'Pharmacy-2.OrganisationType'],
#  ['Dentists-2.Address1', 'CCG-2.Address1'],
#  ['Dentists-2.Address1', 'Clinics-2.Address1'],
#  ['Dentists-2.Address1', 'Hospital-2.Address1'],
#  ['Dentists-2.Address1', 'LAT-2.Address1'],
#  ['Dentists-2.Address1', 'GP_2.Address1'],
#  ['Dentists-2.Address1', 'GPPractices-2.Address1'],
#  ['Dentists-2.Address1', 'SCP-2.Address1'],
#  ['Dentists-2.Address1', 'GSD.Address1'],
#  ['Dentists-2.Address1', 'SCL-2.Address1'],
#  ['Dentists-2.Address1', 'Pharmacy-2.Address1'],
#  ['Dentists-2.Address1', 'SCL-2.Address2'],
#  ['Dentists-2.Address1', 'GSD.Address2'],
#  ['Dentists-2.Address1', 'Dentists-2.Address2'],
#  ['Dentists-2.Address1', 'Hospital-2.Address2'],
#  ['Dentists-2.Address1', 'LAT-2.Address2'],
#  ['Dentists-2.Address1', 'Clinics-2.Address2'],
#  ['Dentists-2.Address1', 'SCP-2.Address2'],
#  ['Dentists-2.Address1', 'Pharmacy-2.Address2'],
#  ['Dentists-2.Address1', 'GP_2.Address2'],
#  ['Dentists-2.Address1', 'CCG-2.Address2'],
#  ['Dentists-2.Address1', 'GPPractices-2.Address2'],
#  ['Dentists-2.Address1', 'SCL-2.Address3'],
#  ['Dentists-2.Address1', 'GP_2.Address3'],
#  ['Dentists-2.Address1', 'LAT-2.Address3'],
#  ['Dentists-2.Address1', 'CCG-2.Address3'],
#  ['Dentists-2.Address1', 'Hospital-2.Address3'],
#  ['Dentists-2.Address1', 'Dentists-2.Address3'],
#  ['Dentists-2.Address1', 'Pharmacy-2.Address3'],
#  ['Dentists-2.Address1', 'GSD.Address3'],
#  ['Dentists-2.Address1', 'Clinics-2.Address3'],
#  ['Dentists-2.Address1', 'SCP-2.Address3'],
#  ['Dentists-2.Address1', 'GPPractices-2.Address3'],
#  ['Dentists-2.Address2', 'LAT-2.Address2'],
#  ['Dentists-2.Address2', 'GP_2.Address2'],
#  ['Dentists-2.Address2', 'SCL-2.Address2'],
#  ['Dentists-2.Address2', 'GSD.Address2'],
#  ['Dentists-2.Address2', 'Clinics-2.Address2'],
#  ['Dentists-2.Address2', 'Pharmacy-2.Address2'],
#  ['Dentists-2.Address2', 'CCG-2.Address2'],
#  ['Dentists-2.Address2', 'GPPractices-2.Address2'],
#  ['Dentists-2.Address2', 'SCP-2.Address2'],
#  ['Dentists-2.Address2', 'Hospital-2.Address2'],
#  ['Dentists-2.Address2', 'CCG-2.Address1'],
#  ['Dentists-2.Address2', 'Hospital-2.Address1'],
#  ['Dentists-2.Address2', 'Clinics-2.Address1'],
#  ['Dentists-2.Address2', 'SCP-2.Address1'],
#  ['Dentists-2.Address2', 'GP_2.Address1'],
#  ['Dentists-2.Address2', 'SCL-2.Address1'],
#  ['Dentists-2.Address2', 'GPPractices-2.Address1'],
#  ['Dentists-2.Address2', 'Pharmacy-2.Address1'],
#  ['Dentists-2.Address2', 'LAT-2.Address1'],
#  ['Dentists-2.Address2', 'GSD.Address1'],
#  ['Dentists-2.Address2', 'Dentists-2.Address1'],
#  ['Dentists-2.Address2', 'SCL-2.Address3'],
#  ['Dentists-2.Address2', 'GP_2.Address3'],
#  ['Dentists-2.Address2', 'LAT-2.Address3'],
#  ['Dentists-2.Address2', 'CCG-2.Address3'],
#  ['Dentists-2.Address2', 'Hospital-2.Address3'],
#  ['Dentists-2.Address2', 'Dentists-2.Address3'],
#  ['Dentists-2.Address2', 'Pharmacy-2.Address3'],
#  ['Dentists-2.Address2', 'GSD.Address3'],
#  ['Dentists-2.Address2', 'Clinics-2.Address3'],
#  ['Dentists-2.Address2', 'SCP-2.Address3'],
#  ['Dentists-2.Address2', 'GPPractices-2.Address3'],
#  ['Dentists-2.Address3', 'SCL-2.Address3'],
#  ['Dentists-2.Address3', 'GPPractices-2.Address3'],
#  ['Dentists-2.Address3', 'Clinics-2.Address3'],
#  ['Dentists-2.Address3', 'SCP-2.Address3'],
#  ['Dentists-2.Address3', 'Pharmacy-2.Address3'],
#  ['Dentists-2.Address3', 'GSD.Address3'],
#  ['Dentists-2.Address3', 'GP_2.Address3'],
#  ['Dentists-2.Address3', 'LAT-2.Address3'],
#  ['Dentists-2.Address3', 'Hospital-2.Address3'],
#  ['Dentists-2.Address3', 'CCG-2.Address3'],
#  ['Dentists-2.Address3', 'SCL-2.Address2'],
#  ['Dentists-2.Address3', 'GSD.Address2'],
#  ['Dentists-2.Address3', 'Dentists-2.Address2'],
#  ['Dentists-2.Address3', 'Hospital-2.Address2'],
#  ['Dentists-2.Address3', 'LAT-2.Address2'],
#  ['Dentists-2.Address3', 'Clinics-2.Address2'],
#  ['Dentists-2.Address3', 'SCP-2.Address2'],
#  ['Dentists-2.Address3', 'Pharmacy-2.Address2'],
#  ['Dentists-2.Address3', 'GP_2.Address2'],
#  ['Dentists-2.Address3', 'CCG-2.Address2'],
#  ['Dentists-2.Address3', 'GPPractices-2.Address2'],
#  ['Dentists-2.Address3', 'CCG-2.Address1'],
#  ['Dentists-2.Address3', 'Hospital-2.Address1'],
#  ['Dentists-2.Address3', 'Clinics-2.Address1'],
#  ['Dentists-2.Address3', 'SCP-2.Address1'],
#  ['Dentists-2.Address3', 'GP_2.Address1'],
#  ['Dentists-2.Address3', 'SCL-2.Address1'],
#  ['Dentists-2.Address3', 'GPPractices-2.Address1'],
#  ['Dentists-2.Address3', 'Pharmacy-2.Address1'],
#  ['Dentists-2.Address3', 'LAT-2.Address1'],
#  ['Dentists-2.Address3', 'GSD.Address1'],
#  ['Dentists-2.Address3', 'Dentists-2.Address1'],
#  ['Dentists-2.City', 'Hospital-2.City'],
#  ['Dentists-2.City', 'Clinics-2.City'],
#  ['Dentists-2.City', 'CCG-2.City'],
#  ['Dentists-2.City', 'GPPractices-2.City'],
#  ['Dentists-2.City', 'SCL-2.City'],
#  ['Dentists-2.City', 'SCP-2.City'],
#  ['Dentists-2.City', 'GP_2.City'],
#  ['Dentists-2.City', 'GSD.City'],
#  ['Dentists-2.City', 'Pharmacy-2.City'],
#  ['Dentists-2.City', 'LAT-2.City'],
#  ['Dentists-2.County', 'CCG-2.County'],
#  ['Dentists-2.County', 'GP_2.County'],
#  ['Dentists-2.County', 'GPPractices-2.County'],
#  ['Dentists-2.County', 'Clinics-2.County'],
#  ['Dentists-2.County', 'SCL-2.County'],
#  ['Dentists-2.County', 'LAT-2.County'],
#  ['Dentists-2.County', 'Hospital-2.County'],
#  ['Dentists-2.County', 'SCP-2.County'],
#  ['Dentists-2.County', 'Pharmacy-2.County'],
#  ['Dentists-2.County', 'GSD.County'],
#  ['Dentists-2.Postcode', 'Pharmacy-2.Postcode'],
#  ['Dentists-2.Postcode', 'Hospital-2.Postcode'],
#  ['Dentists-2.Postcode', 'SCL-2.Postcode'],
#  ['Dentists-2.Postcode', 'SCP-2.Postcode'],
#  ['Dentists-2.Postcode', 'GP_2.Postcode'],
#  ['Dentists-2.Postcode', 'LAT-2.Postcode'],
#  ['Dentists-2.Postcode', 'GSD.Postcode'],
#  ['Dentists-2.Postcode', 'GPPractices-2.Postcode'],
#  ['Dentists-2.Postcode', 'CCG-2.Postcode'],
#  ['Dentists-2.Postcode', 'Clinics-2.Postcode'],
#  ['Dentists-2.Latitude', 'Pharmacy-2.Latitude'],
#  ['Dentists-2.Latitude', 'GP_2.Latitude'],
#  ['Dentists-2.Latitude', 'GSD.Latitude'],
#  ['Dentists-2.Latitude', 'CCG-2.Latitude'],
#  ['Dentists-2.Latitude', 'Clinics-2.Latitude'],
#  ['Dentists-2.Latitude', 'GPPractices-2.Latitude'],
#  ['Dentists-2.Latitude', 'LAT-2.Latitude'],
#  ['Dentists-2.Latitude', 'SCP-2.Latitude'],
#  ['Dentists-2.Latitude', 'Hospital-2.Latitude'],
#  ['Dentists-2.Latitude', 'SCL-2.Latitude'],
#  ['Dentists-2.Longitude', 'GPPractices-2.Longitude'],
#  ['Dentists-2.Longitude', 'SCL-2.Longitude'],
#  ['Dentists-2.Longitude', 'CCG-2.Longitude'],
#  ['Dentists-2.Longitude', 'GSD.Longitude'],
#  ['Dentists-2.Longitude', 'SCP-2.Longitude'],
#  ['Dentists-2.Longitude', 'Clinics-2.Longitude'],
#  ['Dentists-2.Longitude', 'Hospital-2.Longitude'],
#  ['Dentists-2.Longitude', 'LAT-2.Longitude'],
#  ['Dentists-2.Longitude', 'Pharmacy-2.Longitude'],
#  ['Dentists-2.Longitude', 'GP_2.Longitude'],
#  ['Dentists-2.ParentODSCode', 'SCL-2.ParentODSCode'],
#  ['Dentists-2.ParentODSCode', 'GP_2.ParentODSCode'],
#  ['Dentists-2.ParentODSCode', 'Pharmacy-2.ParentODSCode'],
#  ['Dentists-2.ParentODSCode', 'Hospital-2.ParentODSCode'],
#  ['Dentists-2.ParentName', 'SCL-2.ParentName'],
#  ['Dentists-2.ParentName', 'GP_2.ParentName'],
#  ['Dentists-2.ParentName', 'Pharmacy-2.ParentName'],
#  ['Dentists-2.ParentName', 'Hospital-2.ParentName'],
#  ['Dentists-2.Phone', 'Pharmacy-2.Phone'],
#  ['Dentists-2.Phone', 'Hospital-2.Phone'],
#  ['Dentists-2.Phone', 'GP_2.Phone'],
#  ['Dentists-2.Phone', 'CCG-2.Phone'],
#  ['Dentists-2.Phone', 'LAT-2.Phone'],
#  ['Dentists-2.Phone', 'SCL-2.Phone'],
#  ['Dentists-2.Phone', 'Clinics-2.Phone'],
#  ['Dentists-2.Email', 'Clinics-2.Email'],
#  ['Dentists-2.Email', 'Pharmacy-2.Email'],
#  ['Dentists-2.Email', 'GP_2.Email'],
#  ['Dentists-2.Email', 'Hospital-2.Email'],
#  ['Dentists-2.Email', 'LAT-2.Email'],
#  ['Dentists-2.Email', 'SCL-2.Email'],
#  ['Dentists-2.Email', 'CCG-2.Email'],
#  ['Dentists-2.Website', 'Hospital-2.Website'],
#  ['Dentists-2.Website', 'Clinics-2.Website'],
#  ['Dentists-2.Website', 'SCL-2.Website'],
#  ['Dentists-2.Website', 'LAT-2.Website'],
#  ['Dentists-2.Website', 'Pharmacy-2.Website'],
#  ['Dentists-2.Website', 'GP_2.Website'],
#  ['Dentists-2.Website', 'CCG-2.Website'],
#  ['Dentists-2.Fax', 'LAT-2.Fax'],
#  ['Dentists-2.Fax', 'GP_2.Fax'],
#  ['Dentists-2.Fax', 'Pharmacy-2.Fax'],
#  ['Dentists-2.Fax', 'SCL-2.Fax'],
#  ['Dentists-2.Fax', 'Hospital-2.Fax'],
#  ['Dentists-2.Fax', 'CCG-2.Fax'],
#  ['Dentists-2.Fax', 'Clinics-2.Fax'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'GPPractices-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'GP_2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'SCP-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'OpticianOpeningTimes-2.OrganisationId'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'GSD.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'PharmacyOpeningTimes-2.OrganisationId'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'GPOpeningTimes-2.OrganisationId'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'CCG-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'Dentists-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'SCLServices-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'Pharmacy-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'Clinics-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'DentistOpeningTimes-2.OrganisationId'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'SCL-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'PharmacyServices-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'GPServices-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'LAT-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'Hospital-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'GP_2.OrganisationCode'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'SCL-2.OrganisationCode'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'GPPractices-2.OrganisationCode'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'LAT-2.OrganisationCode'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationCode'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'CCG-2.OrganisationCode'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'Clinics-2.OrganisationCode'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'Hospital-2.OrganisationCode'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'Dentists-2.OrganisationCode'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'SCP-2.OrganisationCode'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'Pharmacy-2.OrganisationCode'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationName'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'SCP-2.OrganisationName'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'Clinics-2.OrganisationName'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'LAT-2.OrganisationName'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'SCL-2.OrganisationName'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'GSD.OrganisationName'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'Pharmacy-2.OrganisationName'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'Dentists-2.OrganisationName'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'GPPractices-2.OrganisationName'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'GP_2.OrganisationName'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'Hospital-2.OrganisationName'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'CCG-2.OrganisationName'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'GP_2.OrganisationType'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'LAT-2.OrganisationType'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'GSD.OrganisationType'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'CCG-2.OrganisationType'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'SCP-2.OrganisationType'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'GPPractices-2.OrganisationType'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'Dentists-2.OrganisationType'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'SCL-2.OrganisationType'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'Hospital-2.OrganisationType'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'Clinics-2.OrganisationType'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationID',
#   'Pharmacy-2.OrganisationType'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'GP_2.OrganisationCode'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'SCL-2.OrganisationCode'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'SCP-2.OrganisationCode'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'GPPractices-2.OrganisationCode'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'Clinics-2.OrganisationCode'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'Hospital-2.OrganisationCode'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'Dentists-2.OrganisationCode'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'CCG-2.OrganisationCode'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'LAT-2.OrganisationCode'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'Pharmacy-2.OrganisationCode'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'GPPractices-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'GP_2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'SCP-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'OpticianOpeningTimes-2.OrganisationId'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'Hospital-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'PharmacyOpeningTimes-2.OrganisationId'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'GPOpeningTimes-2.OrganisationId'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'CCG-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'Dentists-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'SCLServices-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'Pharmacy-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'Clinics-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'DentistOpeningTimes-2.OrganisationId'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'PharmacyServices-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'SCL-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'GPServices-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'LAT-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'GSD.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'SCP-2.OrganisationStatus'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'Dentists-2.OrganisationStatus'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'Clinics-2.OrganisationStatus'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'LAT-2.OrganisationStatus'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'GSD.OrganisationStatus'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'Hospital-2.OrganisationStatus'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'SCL-2.OrganisationStatus'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'GP_2.OrganisationStatus'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'GPPractices-2.OrganisationStatus'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'CCG-2.OrganisationStatus'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationCode',
#   'Pharmacy-2.OrganisationStatus'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'GP_2.OrganisationName'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'GSD.OrganisationName'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'SCP-2.OrganisationName'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'Pharmacy-2.OrganisationName'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'Dentists-2.OrganisationName'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'Clinics-2.OrganisationName'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'Hospital-2.OrganisationName'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'GPPractices-2.OrganisationName'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'CCG-2.OrganisationName'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'LAT-2.OrganisationName'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'SCL-2.OrganisationName'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'SCP-2.OrganisationStatus'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'Dentists-2.OrganisationStatus'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'Clinics-2.OrganisationStatus'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'LAT-2.OrganisationStatus'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'GSD.OrganisationStatus'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'Hospital-2.OrganisationStatus'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'SCL-2.OrganisationStatus'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'GP_2.OrganisationStatus'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'GPPractices-2.OrganisationStatus'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'CCG-2.OrganisationStatus'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'Pharmacy-2.OrganisationStatus'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'GPPractices-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'GP_2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'SCP-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'OpticianOpeningTimes-2.OrganisationId'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'Hospital-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'PharmacyOpeningTimes-2.OrganisationId'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'GPOpeningTimes-2.OrganisationId'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'CCG-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'Dentists-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'SCLServices-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'Pharmacy-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'Clinics-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'DentistOpeningTimes-2.OrganisationId'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'SCL-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'PharmacyServices-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'GPServices-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'LAT-2.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'GSD.OrganisationID'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'GP_2.OrganisationType'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'LAT-2.OrganisationType'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'GSD.OrganisationType'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'CCG-2.OrganisationType'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'SCP-2.OrganisationType'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'GPPractices-2.OrganisationType'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'Dentists-2.OrganisationType'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'SCL-2.OrganisationType'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'Hospital-2.OrganisationType'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'Clinics-2.OrganisationType'],
#  ['TransparencyIndicatorsDentistsPerformance-2.OrganisationName',
#   'Pharmacy-2.OrganisationType'],
#  ['GSD.OrganisationID', 'GPPractices-2.OrganisationID'],
#  ['GSD.OrganisationID', 'GP_2.OrganisationID'],
#  ['GSD.OrganisationID', 'SCP-2.OrganisationID'],
#  ['GSD.OrganisationID', 'OpticianOpeningTimes-2.OrganisationId'],
#  ['GSD.OrganisationID', 'PharmacyOpeningTimes-2.OrganisationId'],
#  ['GSD.OrganisationID', 'GPOpeningTimes-2.OrganisationId'],
#  ['GSD.OrganisationID', 'CCG-2.OrganisationID'],
#  ['GSD.OrganisationID', 'Dentists-2.OrganisationID'],
#  ['GSD.OrganisationID', 'SCLServices-2.OrganisationID'],
#  ['GSD.OrganisationID', 'Pharmacy-2.OrganisationID'],
#  ['GSD.OrganisationID',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationID'],
#  ['GSD.OrganisationID', 'Clinics-2.OrganisationID'],
#  ['GSD.OrganisationID', 'DentistOpeningTimes-2.OrganisationId'],
#  ['GSD.OrganisationID', 'SCL-2.OrganisationID'],
#  ['GSD.OrganisationID', 'PharmacyServices-2.OrganisationID'],
#  ['GSD.OrganisationID', 'GPServices-2.OrganisationID'],
#  ['GSD.OrganisationID', 'LAT-2.OrganisationID'],
#  ['GSD.OrganisationID', 'Hospital-2.OrganisationID'],
#  ['GSD.OrganisationID', 'GP_2.OrganisationCode'],
#  ['GSD.OrganisationID', 'SCL-2.OrganisationCode'],
#  ['GSD.OrganisationID', 'GPPractices-2.OrganisationCode'],
#  ['GSD.OrganisationID', 'LAT-2.OrganisationCode'],
#  ['GSD.OrganisationID',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationCode'],
#  ['GSD.OrganisationID', 'CCG-2.OrganisationCode'],
#  ['GSD.OrganisationID', 'Clinics-2.OrganisationCode'],
#  ['GSD.OrganisationID', 'Hospital-2.OrganisationCode'],
#  ['GSD.OrganisationID', 'Dentists-2.OrganisationCode'],
#  ['GSD.OrganisationID', 'SCP-2.OrganisationCode'],
#  ['GSD.OrganisationID', 'Pharmacy-2.OrganisationCode'],
#  ['GSD.OrganisationID',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationName'],
#  ['GSD.OrganisationID', 'SCP-2.OrganisationName'],
#  ['GSD.OrganisationID', 'Clinics-2.OrganisationName'],
#  ['GSD.OrganisationID', 'LAT-2.OrganisationName'],
#  ['GSD.OrganisationID', 'SCL-2.OrganisationName'],
#  ['GSD.OrganisationID', 'GSD.OrganisationName'],
#  ['GSD.OrganisationID', 'Pharmacy-2.OrganisationName'],
#  ['GSD.OrganisationID', 'Dentists-2.OrganisationName'],
#  ['GSD.OrganisationID', 'GPPractices-2.OrganisationName'],
#  ['GSD.OrganisationID', 'GP_2.OrganisationName'],
#  ['GSD.OrganisationID', 'Hospital-2.OrganisationName'],
#  ['GSD.OrganisationID', 'CCG-2.OrganisationName'],
#  ['GSD.OrganisationID', 'GP_2.OrganisationType'],
#  ['GSD.OrganisationID', 'LAT-2.OrganisationType'],
#  ['GSD.OrganisationID', 'GSD.OrganisationType'],
#  ['GSD.OrganisationID', 'CCG-2.OrganisationType'],
#  ['GSD.OrganisationID', 'SCP-2.OrganisationType'],
#  ['GSD.OrganisationID', 'GPPractices-2.OrganisationType'],
#  ['GSD.OrganisationID', 'Dentists-2.OrganisationType'],
#  ['GSD.OrganisationID', 'SCL-2.OrganisationType'],
#  ['GSD.OrganisationID', 'Hospital-2.OrganisationType'],
#  ['GSD.OrganisationID', 'Clinics-2.OrganisationType'],
#  ['GSD.OrganisationID', 'Pharmacy-2.OrganisationType'],
#  ['GSD.OrganisationType', 'SCL-2.OrganisationType'],
#  ['GSD.OrganisationType', 'SCP-2.OrganisationType'],
#  ['GSD.OrganisationType', 'LAT-2.OrganisationType'],
#  ['GSD.OrganisationType', 'GP_2.OrganisationType'],
#  ['GSD.OrganisationType', 'GPPractices-2.OrganisationType'],
#  ['GSD.OrganisationType', 'Hospital-2.OrganisationType'],
#  ['GSD.OrganisationType', 'CCG-2.OrganisationType'],
#  ['GSD.OrganisationType', 'Dentists-2.OrganisationType'],
#  ['GSD.OrganisationType', 'Clinics-2.OrganisationType'],
#  ['GSD.OrganisationType', 'Pharmacy-2.OrganisationType'],
#  ['GSD.OrganisationType', 'SCP-2.OrganisationStatus'],
#  ['GSD.OrganisationType',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationName'],
#  ['GSD.OrganisationType', 'SCP-2.OrganisationName'],
#  ['GSD.OrganisationType', 'Clinics-2.OrganisationName'],
#  ['GSD.OrganisationType', 'Dentists-2.OrganisationStatus'],
#  ['GSD.OrganisationType', 'LAT-2.OrganisationName'],
#  ['GSD.OrganisationType', 'Clinics-2.OrganisationStatus'],
#  ['GSD.OrganisationType', 'SCL-2.OrganisationName'],
#  ['GSD.OrganisationType', 'GSD.OrganisationName'],
#  ['GSD.OrganisationType', 'LAT-2.OrganisationStatus'],
#  ['GSD.OrganisationType', 'GSD.OrganisationStatus'],
#  ['GSD.OrganisationType', 'Pharmacy-2.OrganisationName'],
#  ['GSD.OrganisationType', 'Dentists-2.OrganisationName'],
#  ['GSD.OrganisationType', 'GPPractices-2.OrganisationName'],
#  ['GSD.OrganisationType', 'Hospital-2.OrganisationStatus'],
#  ['GSD.OrganisationType', 'GP_2.OrganisationName'],
#  ['GSD.OrganisationType', 'Hospital-2.OrganisationName'],
#  ['GSD.OrganisationType', 'SCL-2.OrganisationStatus'],
#  ['GSD.OrganisationType', 'GP_2.OrganisationStatus'],
#  ['GSD.OrganisationType', 'GPPractices-2.OrganisationStatus'],
#  ['GSD.OrganisationType', 'CCG-2.OrganisationStatus'],
#  ['GSD.OrganisationType', 'CCG-2.OrganisationName'],
#  ['GSD.OrganisationType', 'Pharmacy-2.OrganisationStatus'],
#  ['GSD.OrganisationType', 'GPPractices-2.OrganisationID'],
#  ['GSD.OrganisationType', 'GP_2.OrganisationID'],
#  ['GSD.OrganisationType', 'SCP-2.OrganisationID'],
#  ['GSD.OrganisationType', 'OpticianOpeningTimes-2.OrganisationId'],
#  ['GSD.OrganisationType', 'Hospital-2.OrganisationID'],
#  ['GSD.OrganisationType', 'PharmacyOpeningTimes-2.OrganisationId'],
#  ['GSD.OrganisationType', 'GPOpeningTimes-2.OrganisationId'],
#  ['GSD.OrganisationType', 'CCG-2.OrganisationID'],
#  ['GSD.OrganisationType', 'Dentists-2.OrganisationID'],
#  ['GSD.OrganisationType', 'SCLServices-2.OrganisationID'],
#  ['GSD.OrganisationType', 'Pharmacy-2.OrganisationID'],
#  ['GSD.OrganisationType',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationID'],
#  ['GSD.OrganisationType', 'Clinics-2.OrganisationID'],
#  ['GSD.OrganisationType', 'DentistOpeningTimes-2.OrganisationId'],
#  ['GSD.OrganisationType', 'SCL-2.OrganisationID'],
#  ['GSD.OrganisationType', 'PharmacyServices-2.OrganisationID'],
#  ['GSD.OrganisationType', 'GPServices-2.OrganisationID'],
#  ['GSD.OrganisationType', 'LAT-2.OrganisationID'],
#  ['GSD.OrganisationType', 'GSD.OrganisationID'],
#  ['GSD.SubType', 'GP_2.SubType'],
#  ['GSD.SubType', 'SCL-2.SubType'],
#  ['GSD.SubType', 'Clinics-2.SubType'],
#  ['GSD.SubType', 'GPPractices-2.SubType'],
#  ['GSD.SubType', 'CCG-2.SubType'],
#  ['GSD.SubType', 'Dentists-2.SubType'],
#  ['GSD.SubType', 'Hospital-2.SubType'],
#  ['GSD.SubType', 'LAT-2.SubType'],
#  ['GSD.SubType', 'SCP-2.SubType'],
#  ['GSD.SubType', 'Pharmacy-2.SubType'],
#  ['GSD.OrganisationStatus', 'SCP-2.OrganisationStatus'],
#  ['GSD.OrganisationStatus', 'LAT-2.OrganisationStatus'],
#  ['GSD.OrganisationStatus', 'GPPractices-2.OrganisationStatus'],
#  ['GSD.OrganisationStatus', 'GP_2.OrganisationStatus'],
#  ['GSD.OrganisationStatus', 'CCG-2.OrganisationStatus'],
#  ['GSD.OrganisationStatus', 'Dentists-2.OrganisationStatus'],
#  ['GSD.OrganisationStatus', 'Hospital-2.OrganisationStatus'],
#  ['GSD.OrganisationStatus', 'Clinics-2.OrganisationStatus'],
#  ['GSD.OrganisationStatus', 'SCL-2.OrganisationStatus'],
#  ['GSD.OrganisationStatus', 'Pharmacy-2.OrganisationStatus'],
#  ['GSD.OrganisationStatus',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationName'],
#  ['GSD.OrganisationStatus', 'SCP-2.OrganisationName'],
#  ['GSD.OrganisationStatus', 'Clinics-2.OrganisationName'],
#  ['GSD.OrganisationStatus', 'LAT-2.OrganisationName'],
#  ['GSD.OrganisationStatus', 'SCL-2.OrganisationName'],
#  ['GSD.OrganisationStatus', 'GSD.OrganisationName'],
#  ['GSD.OrganisationStatus', 'Pharmacy-2.OrganisationName'],
#  ['GSD.OrganisationStatus', 'Dentists-2.OrganisationName'],
#  ['GSD.OrganisationStatus', 'GPPractices-2.OrganisationName'],
#  ['GSD.OrganisationStatus', 'GP_2.OrganisationName'],
#  ['GSD.OrganisationStatus', 'Hospital-2.OrganisationName'],
#  ['GSD.OrganisationStatus', 'CCG-2.OrganisationName'],
#  ['GSD.OrganisationStatus', 'GP_2.OrganisationType'],
#  ['GSD.OrganisationStatus', 'LAT-2.OrganisationType'],
#  ['GSD.OrganisationStatus', 'GSD.OrganisationType'],
#  ['GSD.OrganisationStatus', 'CCG-2.OrganisationType'],
#  ['GSD.OrganisationStatus', 'SCP-2.OrganisationType'],
#  ['GSD.OrganisationStatus', 'GPPractices-2.OrganisationType'],
#  ['GSD.OrganisationStatus', 'Dentists-2.OrganisationType'],
#  ['GSD.OrganisationStatus', 'SCL-2.OrganisationType'],
#  ['GSD.OrganisationStatus', 'Hospital-2.OrganisationType'],
#  ['GSD.OrganisationStatus', 'Clinics-2.OrganisationType'],
#  ['GSD.OrganisationStatus', 'Pharmacy-2.OrganisationType'],
#  ['GSD.OrganisationStatus', 'GP_2.OrganisationCode'],
#  ['GSD.OrganisationStatus', 'SCL-2.OrganisationCode'],
#  ['GSD.OrganisationStatus', 'GPPractices-2.OrganisationCode'],
#  ['GSD.OrganisationStatus',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationCode'],
#  ['GSD.OrganisationStatus', 'LAT-2.OrganisationCode'],
#  ['GSD.OrganisationStatus', 'CCG-2.OrganisationCode'],
#  ['GSD.OrganisationStatus', 'Clinics-2.OrganisationCode'],
#  ['GSD.OrganisationStatus', 'Hospital-2.OrganisationCode'],
#  ['GSD.OrganisationStatus', 'Dentists-2.OrganisationCode'],
#  ['GSD.OrganisationStatus', 'SCP-2.OrganisationCode'],
#  ['GSD.OrganisationStatus', 'Pharmacy-2.OrganisationCode'],
#  ['GSD.OrganisationName', 'GP_2.OrganisationName'],
#  ['GSD.OrganisationName',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationName'],
#  ['GSD.OrganisationName', 'SCP-2.OrganisationName'],
#  ['GSD.OrganisationName', 'Pharmacy-2.OrganisationName'],
#  ['GSD.OrganisationName', 'Dentists-2.OrganisationName'],
#  ['GSD.OrganisationName', 'Clinics-2.OrganisationName'],
#  ['GSD.OrganisationName', 'Hospital-2.OrganisationName'],
#  ['GSD.OrganisationName', 'GPPractices-2.OrganisationName'],
#  ['GSD.OrganisationName', 'CCG-2.OrganisationName'],
#  ['GSD.OrganisationName', 'LAT-2.OrganisationName'],
#  ['GSD.OrganisationName', 'SCL-2.OrganisationName'],
#  ['GSD.OrganisationName', 'SCP-2.OrganisationStatus'],
#  ['GSD.OrganisationName', 'Dentists-2.OrganisationStatus'],
#  ['GSD.OrganisationName', 'Clinics-2.OrganisationStatus'],
#  ['GSD.OrganisationName', 'LAT-2.OrganisationStatus'],
#  ['GSD.OrganisationName', 'GSD.OrganisationStatus'],
#  ['GSD.OrganisationName', 'Hospital-2.OrganisationStatus'],
#  ['GSD.OrganisationName', 'SCL-2.OrganisationStatus'],
#  ['GSD.OrganisationName', 'GP_2.OrganisationStatus'],
#  ['GSD.OrganisationName', 'GPPractices-2.OrganisationStatus'],
#  ['GSD.OrganisationName', 'CCG-2.OrganisationStatus'],
#  ['GSD.OrganisationName', 'Pharmacy-2.OrganisationStatus'],
#  ['GSD.OrganisationName', 'GPPractices-2.OrganisationID'],
#  ['GSD.OrganisationName', 'GP_2.OrganisationID'],
#  ['GSD.OrganisationName', 'SCP-2.OrganisationID'],
#  ['GSD.OrganisationName', 'OpticianOpeningTimes-2.OrganisationId'],
#  ['GSD.OrganisationName', 'Hospital-2.OrganisationID'],
#  ['GSD.OrganisationName', 'PharmacyOpeningTimes-2.OrganisationId'],
#  ['GSD.OrganisationName', 'GPOpeningTimes-2.OrganisationId'],
#  ['GSD.OrganisationName', 'CCG-2.OrganisationID'],
#  ['GSD.OrganisationName', 'Dentists-2.OrganisationID'],
#  ['GSD.OrganisationName', 'SCLServices-2.OrganisationID'],
#  ['GSD.OrganisationName', 'Pharmacy-2.OrganisationID'],
#  ['GSD.OrganisationName',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationID'],
#  ['GSD.OrganisationName', 'Clinics-2.OrganisationID'],
#  ['GSD.OrganisationName', 'DentistOpeningTimes-2.OrganisationId'],
#  ['GSD.OrganisationName', 'SCL-2.OrganisationID'],
#  ['GSD.OrganisationName', 'PharmacyServices-2.OrganisationID'],
#  ['GSD.OrganisationName', 'GPServices-2.OrganisationID'],
#  ['GSD.OrganisationName', 'LAT-2.OrganisationID'],
#  ['GSD.OrganisationName', 'GSD.OrganisationID'],
#  ['GSD.OrganisationName', 'GP_2.OrganisationType'],
#  ['GSD.OrganisationName', 'LAT-2.OrganisationType'],
#  ['GSD.OrganisationName', 'GSD.OrganisationType'],
#  ['GSD.OrganisationName', 'CCG-2.OrganisationType'],
#  ['GSD.OrganisationName', 'SCP-2.OrganisationType'],
#  ['GSD.OrganisationName', 'GPPractices-2.OrganisationType'],
#  ['GSD.OrganisationName', 'Dentists-2.OrganisationType'],
#  ['GSD.OrganisationName', 'SCL-2.OrganisationType'],
#  ['GSD.OrganisationName', 'Hospital-2.OrganisationType'],
#  ['GSD.OrganisationName', 'Clinics-2.OrganisationType'],
#  ['GSD.OrganisationName', 'Pharmacy-2.OrganisationType'],
#  ['GSD.Address1', 'CCG-2.Address1'],
#  ['GSD.Address1', 'Clinics-2.Address1'],
#  ['GSD.Address1', 'Hospital-2.Address1'],
#  ['GSD.Address1', 'LAT-2.Address1'],
#  ['GSD.Address1', 'GP_2.Address1'],
#  ['GSD.Address1', 'GPPractices-2.Address1'],
#  ['GSD.Address1', 'SCP-2.Address1'],
#  ['GSD.Address1', 'SCL-2.Address1'],
#  ['GSD.Address1', 'Dentists-2.Address1'],
#  ['GSD.Address1', 'Pharmacy-2.Address1'],
#  ['GSD.Address1', 'SCL-2.Address2'],
#  ['GSD.Address1', 'GSD.Address2'],
#  ['GSD.Address1', 'Dentists-2.Address2'],
#  ['GSD.Address1', 'Hospital-2.Address2'],
#  ['GSD.Address1', 'LAT-2.Address2'],
#  ['GSD.Address1', 'Clinics-2.Address2'],
#  ['GSD.Address1', 'SCP-2.Address2'],
#  ['GSD.Address1', 'Pharmacy-2.Address2'],
#  ['GSD.Address1', 'GP_2.Address2'],
#  ['GSD.Address1', 'CCG-2.Address2'],
#  ['GSD.Address1', 'GPPractices-2.Address2'],
#  ['GSD.Address1', 'SCL-2.Address3'],
#  ['GSD.Address1', 'GP_2.Address3'],
#  ['GSD.Address1', 'LAT-2.Address3'],
#  ['GSD.Address1', 'CCG-2.Address3'],
#  ['GSD.Address1', 'Hospital-2.Address3'],
#  ['GSD.Address1', 'Dentists-2.Address3'],
#  ['GSD.Address1', 'Pharmacy-2.Address3'],
#  ['GSD.Address1', 'GSD.Address3'],
#  ['GSD.Address1', 'Clinics-2.Address3'],
#  ['GSD.Address1', 'SCP-2.Address3'],
#  ['GSD.Address1', 'GPPractices-2.Address3'],
#  ['GSD.Address2', 'LAT-2.Address2'],
#  ['GSD.Address2', 'GP_2.Address2'],
#  ['GSD.Address2', 'SCL-2.Address2'],
#  ['GSD.Address2', 'Clinics-2.Address2'],
#  ['GSD.Address2', 'Dentists-2.Address2'],
#  ['GSD.Address2', 'Pharmacy-2.Address2'],
#  ['GSD.Address2', 'CCG-2.Address2'],
#  ['GSD.Address2', 'GPPractices-2.Address2'],
#  ['GSD.Address2', 'SCP-2.Address2'],
#  ['GSD.Address2', 'Hospital-2.Address2'],
#  ['GSD.Address2', 'CCG-2.Address1'],
#  ['GSD.Address2', 'Hospital-2.Address1'],
#  ['GSD.Address2', 'Clinics-2.Address1'],
#  ['GSD.Address2', 'SCP-2.Address1'],
#  ['GSD.Address2', 'GP_2.Address1'],
#  ['GSD.Address2', 'SCL-2.Address1'],
#  ['GSD.Address2', 'GPPractices-2.Address1'],
#  ['GSD.Address2', 'Pharmacy-2.Address1'],
#  ['GSD.Address2', 'LAT-2.Address1'],
#  ['GSD.Address2', 'GSD.Address1'],
#  ['GSD.Address2', 'Dentists-2.Address1'],
#  ['GSD.Address2', 'SCL-2.Address3'],
#  ['GSD.Address2', 'GP_2.Address3'],
#  ['GSD.Address2', 'LAT-2.Address3'],
#  ['GSD.Address2', 'CCG-2.Address3'],
#  ['GSD.Address2', 'Hospital-2.Address3'],
#  ['GSD.Address2', 'Dentists-2.Address3'],
#  ['GSD.Address2', 'Pharmacy-2.Address3'],
#  ['GSD.Address2', 'GSD.Address3'],
#  ['GSD.Address2', 'Clinics-2.Address3'],
#  ['GSD.Address2', 'SCP-2.Address3'],
#  ['GSD.Address2', 'GPPractices-2.Address3'],
#  ['GSD.Address3', 'SCL-2.Address3'],
#  ['GSD.Address3', 'GPPractices-2.Address3'],
#  ['GSD.Address3', 'Clinics-2.Address3'],
#  ['GSD.Address3', 'Dentists-2.Address3'],
#  ['GSD.Address3', 'SCP-2.Address3'],
#  ['GSD.Address3', 'Pharmacy-2.Address3'],
#  ['GSD.Address3', 'GP_2.Address3'],
#  ['GSD.Address3', 'LAT-2.Address3'],
#  ['GSD.Address3', 'Hospital-2.Address3'],
#  ['GSD.Address3', 'CCG-2.Address3'],
#  ['GSD.Address3', 'SCL-2.Address2'],
#  ['GSD.Address3', 'GSD.Address2'],
#  ['GSD.Address3', 'Dentists-2.Address2'],
#  ['GSD.Address3', 'Hospital-2.Address2'],
#  ['GSD.Address3', 'LAT-2.Address2'],
#  ['GSD.Address3', 'Clinics-2.Address2'],
#  ['GSD.Address3', 'SCP-2.Address2'],
#  ['GSD.Address3', 'Pharmacy-2.Address2'],
#  ['GSD.Address3', 'GP_2.Address2'],
#  ['GSD.Address3', 'CCG-2.Address2'],
#  ['GSD.Address3', 'GPPractices-2.Address2'],
#  ['GSD.Address3', 'CCG-2.Address1'],
#  ['GSD.Address3', 'Hospital-2.Address1'],
#  ['GSD.Address3', 'Clinics-2.Address1'],
#  ['GSD.Address3', 'SCP-2.Address1'],
#  ['GSD.Address3', 'GP_2.Address1'],
#  ['GSD.Address3', 'SCL-2.Address1'],
#  ['GSD.Address3', 'GPPractices-2.Address1'],
#  ['GSD.Address3', 'Pharmacy-2.Address1'],
#  ['GSD.Address3', 'LAT-2.Address1'],
#  ['GSD.Address3', 'GSD.Address1'],
#  ['GSD.Address3', 'Dentists-2.Address1'],
#  ['GSD.City', 'Hospital-2.City'],
#  ['GSD.City', 'Clinics-2.City'],
#  ['GSD.City', 'CCG-2.City'],
#  ['GSD.City', 'GPPractices-2.City'],
#  ['GSD.City', 'SCL-2.City'],
#  ['GSD.City', 'SCP-2.City'],
#  ['GSD.City', 'GP_2.City'],
#  ['GSD.City', 'Pharmacy-2.City'],
#  ['GSD.City', 'Dentists-2.City'],
#  ['GSD.City', 'LAT-2.City'],
#  ['GSD.County', 'CCG-2.County'],
#  ['GSD.County', 'GP_2.County'],
#  ['GSD.County', 'GPPractices-2.County'],
#  ['GSD.County', 'Clinics-2.County'],
#  ['GSD.County', 'SCL-2.County'],
#  ['GSD.County', 'LAT-2.County'],
#  ['GSD.County', 'Hospital-2.County'],
#  ['GSD.County', 'SCP-2.County'],
#  ['GSD.County', 'Pharmacy-2.County'],
#  ['GSD.County', 'Dentists-2.County'],
#  ['GSD.Postcode', 'Pharmacy-2.Postcode'],
#  ['GSD.Postcode', 'Dentists-2.Postcode'],
#  ['GSD.Postcode', 'Hospital-2.Postcode'],
#  ['GSD.Postcode', 'SCL-2.Postcode'],
#  ['GSD.Postcode', 'SCP-2.Postcode'],
#  ['GSD.Postcode', 'GP_2.Postcode'],
#  ['GSD.Postcode', 'LAT-2.Postcode'],
#  ['GSD.Postcode', 'GPPractices-2.Postcode'],
#  ['GSD.Postcode', 'CCG-2.Postcode'],
#  ['GSD.Postcode', 'Clinics-2.Postcode'],
#  ['GSD.Latitude', 'Dentists-2.Latitude'],
#  ['GSD.Latitude', 'Pharmacy-2.Latitude'],
#  ['GSD.Latitude', 'GP_2.Latitude'],
#  ['GSD.Latitude', 'CCG-2.Latitude'],
#  ['GSD.Latitude', 'Clinics-2.Latitude'],
#  ['GSD.Latitude', 'GPPractices-2.Latitude'],
#  ['GSD.Latitude', 'LAT-2.Latitude'],
#  ['GSD.Latitude', 'SCP-2.Latitude'],
#  ['GSD.Latitude', 'Hospital-2.Latitude'],
#  ['GSD.Latitude', 'SCL-2.Latitude'],
#  ['GSD.Longitude', 'GPPractices-2.Longitude'],
#  ['GSD.Longitude', 'SCL-2.Longitude'],
#  ['GSD.Longitude', 'CCG-2.Longitude'],
#  ['GSD.Longitude', 'Dentists-2.Longitude'],
#  ['GSD.Longitude', 'SCP-2.Longitude'],
#  ['GSD.Longitude', 'Clinics-2.Longitude'],
#  ['GSD.Longitude', 'Hospital-2.Longitude'],
#  ['GSD.Longitude', 'LAT-2.Longitude'],
#  ['GSD.Longitude', 'Pharmacy-2.Longitude'],
#  ['GSD.Longitude', 'GP_2.Longitude'],
#  ['GPServices-2.OrganisationID', 'GPPractices-2.OrganisationID'],
#  ['GPServices-2.OrganisationID', 'GP_2.OrganisationID'],
#  ['GPServices-2.OrganisationID', 'SCP-2.OrganisationID'],
#  ['GPServices-2.OrganisationID', 'OpticianOpeningTimes-2.OrganisationId'],
#  ['GPServices-2.OrganisationID', 'GSD.OrganisationID'],
#  ['GPServices-2.OrganisationID', 'PharmacyOpeningTimes-2.OrganisationId'],
#  ['GPServices-2.OrganisationID', 'GPOpeningTimes-2.OrganisationId'],
#  ['GPServices-2.OrganisationID', 'CCG-2.OrganisationID'],
#  ['GPServices-2.OrganisationID', 'Dentists-2.OrganisationID'],
#  ['GPServices-2.OrganisationID', 'SCLServices-2.OrganisationID'],
#  ['GPServices-2.OrganisationID', 'Pharmacy-2.OrganisationID'],
#  ['GPServices-2.OrganisationID',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationID'],
#  ['GPServices-2.OrganisationID', 'Clinics-2.OrganisationID'],
#  ['GPServices-2.OrganisationID', 'DentistOpeningTimes-2.OrganisationId'],
#  ['GPServices-2.OrganisationID', 'SCL-2.OrganisationID'],
#  ['GPServices-2.OrganisationID', 'PharmacyServices-2.OrganisationID'],
#  ['GPServices-2.OrganisationID', 'LAT-2.OrganisationID'],
#  ['GPServices-2.OrganisationID', 'Hospital-2.OrganisationID'],
#  ['GPServices-2.OrganisationID', 'GP_2.OrganisationCode'],
#  ['GPServices-2.OrganisationID', 'SCL-2.OrganisationCode'],
#  ['GPServices-2.OrganisationID', 'GPPractices-2.OrganisationCode'],
#  ['GPServices-2.OrganisationID', 'LAT-2.OrganisationCode'],
#  ['GPServices-2.OrganisationID',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationCode'],
#  ['GPServices-2.OrganisationID', 'CCG-2.OrganisationCode'],
#  ['GPServices-2.OrganisationID', 'Clinics-2.OrganisationCode'],
#  ['GPServices-2.OrganisationID', 'Hospital-2.OrganisationCode'],
#  ['GPServices-2.OrganisationID', 'Dentists-2.OrganisationCode'],
#  ['GPServices-2.OrganisationID', 'SCP-2.OrganisationCode'],
#  ['GPServices-2.OrganisationID', 'Pharmacy-2.OrganisationCode'],
#  ['GPServices-2.OrganisationID',
#   'TransparencyIndicatorsDentistsPerformance-2.OrganisationName'],
#  ['GPServices-2.OrganisationID', 'SCP-2.OrganisationName'],
#  ['GPServices-2.OrganisationID', 'Clinics-2.OrganisationName'],
#  ['GPServices-2.OrganisationID', 'LAT-2.OrganisationName'],
#  ['GPServices-2.OrganisationID', 'SCL-2.OrganisationName'],
#  ['GPServices-2.OrganisationID', 'GSD.OrganisationName'],
#  ['GPServices-2.OrganisationID', 'Pharmacy-2.OrganisationName'],
#  ['GPServices-2.OrganisationID', 'Dentists-2.OrganisationName'],
#  ['GPServices-2.OrganisationID', 'GPPractices-2.OrganisationName'],
#  ['GPServices-2.OrganisationID', 'GP_2.OrganisationName'],
#  ['GPServices-2.OrganisationID', 'Hospital-2.OrganisationName'],
#  ['GPServices-2.OrganisationID', 'CCG-2.OrganisationName'],
#  ['GPServices-2.OrganisationID', 'GP_2.OrganisationType'],
#  ['GPServices-2.OrganisationID', 'LAT-2.OrganisationType'],
#  ['GPServices-2.OrganisationID', 'GSD.OrganisationType'],
#  ['GPServices-2.OrganisationID', 'CCG-2.OrganisationType'],
#  ['GPServices-2.OrganisationID', 'SCP-2.OrganisationType'],
#  ['GPServices-2.OrganisationID', 'GPPractices-2.OrganisationType'],
#  ['GPServices-2.OrganisationID', 'Dentists-2.OrganisationType'],
#  ['GPServices-2.OrganisationID', 'SCL-2.OrganisationType'],
#  ['GPServices-2.OrganisationID', 'Hospital-2.OrganisationType'],
#  ['GPServices-2.OrganisationID', 'Clinics-2.OrganisationType'],
#  ['GPServices-2.OrganisationID', 'Pharmacy-2.OrganisationType'],
#  ['GPServices-2.ServiceName', 'SCLServices-2.ServiceName'],
#  ['GPServices-2.ServiceName', 'PharmacyServices-2.ServiceName'],
#  ['GPServices-2.ServiceName', 'GPServices-2'],
#  ['PharmacyOpeningTimes-2.OrganisationId', 'GPPractices-2.OrganisationID'],
#  ['PharmacyOpeningTimes-2.OrganisationId', 'GP_2.OrganisationID'],
#  ['PharmacyOpeningTimes-2.OrganisationId', 'SCP-2.OrganisationID'],
#  ['PharmacyOpeningTimes-2.OrganisationId',
#   'OpticianOpeningTimes-2.OrganisationId'],
#  ...]

# %%
clusters_rand_score = compute_rand_score(clusters,gt_clusters)
clusters_rand_score
# Out:
# 0.5497076023391813

# %%
relationships
# Out:
# [[['Dentists-2.OrganisationID', 'DentistOpeningTimes-2.OrganisationId']],
#  [['SCL-2.OrganisationID', 'SCLServices-2.OrganisationID']],
#  [['Pharmacy-2.OrganisationID', 'PharmacyOpeningTimes-2.OrganisationId']],
#  [['Pharmacy-2.OrganisationID', 'PharmacyServices-2.OrganisationID']],
#  [['GP_2.OrganisationID', 'GPOpeningTimes-2.OrganisationId'],
#   ['GP_2.OrganisationID', 'GPServices-2.OrganisationID']]]

# %%
foreign_key(indexes,primary_keys,data_path)
# Out:
# [['Dentists-2.OrganisationID', 'DentistOpeningTimes-2.OrganisationId'],
#  ['SCL-2.OrganisationID', 'SCLServices-2.OrganisationID'],
#  ['Pharmacy-2.OrganisationID', 'PharmacyOpeningTimes-2.OrganisationId'],
#  ['Pharmacy-2.OrganisationID', 'PharmacyServices-2.OrganisationID'],
#  ['GP_2.OrganisationID', 'GPOpeningTimes-2.OrganisationId'],
#  ['GP_2.OrganisationID', 'GPServices-2.OrganisationID'],
#  ['GP_2.OrganisationCode', 'GPPractices-2.OrganisationCode'],
#  ['CCG-2.OrganisationCode', 'GP_2.ParentODSCode'],
#  ['CCG-2.OrganisationName', 'GP_2.ParentName']]

# %%
relationships_rand_score = compute_rand_score_relationships(relationships, gt_relationships)
relationships_rand_score
# Out:
# a =  0
# b =  8
# c =  6
# d =  1
# e =  0
# 0.5333333333333333
